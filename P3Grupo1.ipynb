# %% [markdown]
# <a href="https://colab.research.google.com/github/GallardoCarmen/APRENDIZAJE_AUTOMATICO_23_24/blob/main/P3Grupo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AA_PRACTICA3_GRUPO_NºA01
# Carmen Gallardo, Marta Herraiz y Pablo Mendieta

# %% [markdown]
# # **1.- DEFINICIÓN DEL PROBLEMA**

# %% [markdown]
# El problema que nos enfrentamos es una clasificación de imágenes utilizando un modelo de Red Neuronal Convolucional (CNN). Utilizaremos el conjunto de datos CIFAR-100, que consta de imágenes en color de 32x32 píxeles, distribuidas en 100 clases y agrupadas en 20 superclases. Cada imagen tiene una etiqueta "fina" que representa la clase específica y una etiqueta "gruesa" que indica la superclase a la que pertenece. la información sobre esta base de datos se ha obtenido de  https://www.cs.toronto.edu/~kriz/cifar.html
#
# Descripción del Conjunto de Datos CIFAR-100:
#
# * **Número de Clases:** 100
# * **Número de Superclases:** 20
# * **Número de Imágenes por Clase:** 600
# * **División de Conjuntos de Entrenamiento y Prueba por Clase:**
#
#   500 imágenes de entrenamiento por clase.
#
#   100 imágenes de prueba por clase.
#
# OBJETIVO:
# El objetivo es predecir a qué superclase y clase pertecenecen las imágenes del conjunto de test. Por lo que nos estamos enfrentando a un problema de **clasificación multiclase y una etiqueta**.

# %% [markdown]
# **Librerias necesarias para el modelo:**

# %%
# Importar la versión 2.x de TensorFlow
# %tensorflow_version 2.x

# TensorFlow y Keras
import tensorflow as tf
from tensorflow import keras

# NumPy para manipulación de matrices
import numpy as np

# pyplot de Matplotlib para visualización
import matplotlib.pyplot as plt
print(tf.__version__)

# clases específicas de Keras para construir el modelo
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization

# Importar utilidades de Keras para codificación one-hot
from keras.utils import to_categorical

# conjunto de datos CIFAR-100 de Keras
from keras.datasets import cifar100

# OpenCV para manipulación de imágenes
import cv2

# capa de Dropout de Keras para regularización
from keras.layers import Dropout

# funciones específicas de procesamiento de imágenes de SciPy y skimage
from scipy.ndimage import convolve
from skimage import exposure, filters

# generador de imágenes de Keras para aumento de datos
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from collections import Counter

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.utils import shuffle

from scipy.ndimage import zoom
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# 2.14.0

# %% [markdown]
# Funciones usadas:

# %%
def obtener_clase(etiqueta):
    clases = [
    "beaver", "dolphin", "otter", "seal", "whale",
    "aquarium fish", "flatfish", "ray", "shark", "trout",
    "orchids", "poppies", "roses", "sunflowers", "tulips",
    "bottles", "bowls", "cans", "cups", "plates",
    "apples", "mushrooms", "oranges", "pears", "sweet peppers",
    "clock", "computer keyboard", "lamp", "telephone", "television",
    "bed", "chair", "couch", "table", "wardrobe",
    "bee", "beetle", "butterfly", "caterpillar", "cockroach",
    "bear", "leopard", "lion", "tiger", "wolf",
    "bridge", "castle", "house", "road", "skyscraper",
    "cloud", "forest", "mountain", "plain", "sea",
    "camel", "cattle", "chimpanzee", "elephant", "kangaroo",
    "fox", "porcupine", "possum", "raccoon", "skunk",
    "crab", "lobster", "snail", "spider", "worm",
    "baby", "boy", "girl", "man", "woman",
    "crocodile", "dinosaur", "lizard", "snake", "turtle",
    "hamster", "mouse", "rabbit", "shrew", "squirrel",
    "maple", "oak", "palm", "pine", "willow",
    "bicycle", "bus", "motorcycle", "pickup truck", "train",
    "lawn-mower", "rocket", "streetcar", "tank", "tractor"
    ]

    clases.sort()
    indice_clase = etiqueta.argmax()

    return clases[indice_clase]

def obtener_clase_nocat(n):
    clases = [
    "beaver", "dolphin", "otter", "seal", "whale",
    "aquarium fish", "flatfish", "ray", "shark", "trout",
    "orchids", "poppies", "roses", "sunflowers", "tulips",
    "bottles", "bowls", "cans", "cups", "plates",
    "apples", "mushrooms", "oranges", "pears", "sweet peppers",
    "clock", "computer keyboard", "lamp", "telephone", "television",
    "bed", "chair", "couch", "table", "wardrobe",
    "bee", "beetle", "butterfly", "caterpillar", "cockroach",
    "bear", "leopard", "lion", "tiger", "wolf",
    "bridge", "castle", "house", "road", "skyscraper",
    "cloud", "forest", "mountain", "plain", "sea",
    "camel", "cattle", "chimpanzee", "elephant", "kangaroo",
    "fox", "porcupine", "possum", "raccoon", "skunk",
    "crab", "lobster", "snail", "spider", "worm",
    "baby", "boy", "girl", "man", "woman",
    "crocodile", "dinosaur", "lizard", "snake", "turtle",
    "hamster", "mouse", "rabbit", "shrew", "squirrel",
    "maple", "oak", "palm", "pine", "willow",
    "bicycle", "bus", "motorcycle", "pickup truck", "train",
    "lawn-mower", "rocket", "streetcar", "tank", "tractor"
    ]

    clases.sort()

    return clases[n]

def obtener_superclase(etiqueta):
    superclase = ["aquatic mammals", "fish", "flowers", "food containers", "fruit and vegetables",
                  "household electrical devices", "household furniture", "insects", "large carnivores",
                  "large man-made outdoor things", "large natural outdoor scenes", "large omnivores and herbivores",
                  "medium-sized mammals", "non-insect invertebrates", "people", "reptiles", "small mammals",
                  "trees", "vehicles 1", "vehicles 2"]


    indice_supclase = etiqueta.argmax()
    return superclase [indice_supclase]

#Esta función obtiene la super clase a partir de la clase
def obtener_superclase_Desde_Clase(clase):
    clases_organizadas = {
        'aquatic mammals': ['beaver', 'dolphin', 'otter', 'seal', 'whale'],
        'fish': ['aquarium fish', 'flatfish', 'ray', 'shark', 'trout'],
        'flowers': ['orchids', 'poppies', 'roses', 'sunflowers', 'tulips'],
        'food containers': ['bottles', 'bowls', 'cans', 'cups', 'plates'],
        'fruit and vegetables': ['apples', 'mushrooms', 'oranges', 'pears', 'sweet peppers'],
        'household electrical devices': ['clock', 'computer keyboard', 'lamp', 'telephone', 'television'],
        'household furniture': ['bed', 'chair', 'couch', 'table', 'wardrobe'],
        'insects': ['bee', 'beetle', 'butterfly', 'caterpillar', 'cockroach'],
        'large carnivores': ['bear', 'leopard', 'lion', 'tiger', 'wolf'],
        'large man-made outdoor things': ['bridge', 'castle', 'house', 'road', 'skyscraper'],
        'large natural outdoor scenes': ['cloud', 'forest', 'mountain', 'plain', 'sea'],
        'large omnivores and herbivores': ['camel', 'cattle', 'chimpanzee', 'elephant', 'kangaroo'],
        'medium-sized mammals': ['fox', 'porcupine', 'possum', 'raccoon', 'skunk'],
        'non-insect invertebrates': ['crab', 'lobster', 'snail', 'spider', 'worm'],
        'people': ['baby', 'boy', 'girl', 'man', 'woman'],
        'reptiles': ['crocodile', 'dinosaur', 'lizard', 'snake', 'turtle'],
        'small mammals': ['hamster', 'mouse', 'rabbit', 'shrew', 'squirrel'],
        'trees': ['maple', 'oak', 'palm', 'pine', 'willow'],
        'vehicles 1': ['bicycle', 'bus', 'motorcycle', 'pickup truck', 'train'],
        'vehicles 2': ['lawn-mower', 'rocket', 'streetcar', 'tank', 'tractor']
    }

    for superclase, clases in clases_organizadas.items():
        if clase in clases:
            return superclase

# %% [markdown]
# # **2.- MEDIDA DE ÉXITO**

# %% [markdown]
# Buscamos que nuestro modelo tenga la mayor precisión posible a la hora de clasificar las imágenes. Podemos considerar que si el modelo proporciona una precisión mayor al 1% se podría considerar éxito, debido a que tenemos 100 tipos de clases diferentes y sería más eficiente que hacerlo al azar.
#
# Primero vamos a comprobar la distribución de las clases para asegurarnos que están **equilibradas:**

# %%
# Cargar y dividir el conjunto de datos CIFAR-100
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# Convertir las etiquetas de entrenamiento a una matriz unidimensional
train_labels_flat = train_labels.flatten()
class_counts_train = Counter(train_labels_flat)

# Convertir las etiquetas de prueba a una matriz unidimensional
test_labels_flat = test_labels.flatten()

class_counts_test = Counter(test_labels_flat)
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Gráfica para el conjunto de entrenamiento
axs[0].bar(class_counts_train.keys(), class_counts_train.values(), color='blue')
axs[0].set_xlabel('Clase')
axs[0].set_ylabel('Número de Imágenes')
axs[0].set_title('Distribución de Clases en CIFAR-100 (Conjunto de Entrenamiento)')

# Gráfica para el conjunto de prueba
axs[1].bar(class_counts_test.keys(), class_counts_test.values(), color='orange')
axs[1].set_xlabel('Clase')
axs[1].set_ylabel('Número de Imágenes')
axs[1].set_title('Distribución de Clases en CIFAR-100 (Conjunto de Test)')

# Ajustar el diseño para evitar solapamiento
plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 3s 0us/step

# %% [markdown]
# Podemos observar que las clases están equilibradas. Gracias a esto, nos aseguramos de evitar sesgos en el entrenamiento.

# %% [markdown]
# # **3.- DECISIÓN DE UN PROTOCOLO DE EVALUACIÓN**

# %% [markdown]
# Para medir el progreso acutal, el proceso de evaluación que elegimos va a ser **contar un conjunto de validación hold-out**, debido que tenemos un conjunto con muchos datos.
#
# Para ello, dividiremos los datos de entrenamiento en dos conjuntos:
#
# *   Datos de entrenamiento: 40.000 datos
# *   Datos de validación: 10.000 datos

# %% [markdown]
# # **4.- PREPARACIÓN DE LOS DATOS**

# %% [markdown]
# ### Trasformaciones fundamentales
# Tenemos que dar los datos al modelo en formato adecuado.
#
# *   Formatear los datos como **tensores**.
# *   **Normalizar** los valores : [ 0, 1 ]
# *   Generar más **imágenes**. (apartado 7)
# *   Hacer **shuffle** con las imágenes
# *   Hacer **ingeniería de Características**.
#
# Lo primero que vamos a hacer es cargar los todos datos, incluyendo las etiquetas, tanto las de la categoría fina como las de la gruesa. Por otro lado, observamos la forma de los tensores de los datos.

# %%
#obtenicon de los datos
(train_images, train_labels_fine), (test_images, test_labels_fine) = cifar100.load_data(label_mode='fine')
(_, train_labels_coarse), (_, test_labels_coarse) = cifar100.load_data(label_mode='coarse')

print ("tamaño imagenes entrenamiento: ", train_images.shape)
print ("tamaño etiquetas entrenamiento finas: ", train_labels_fine.shape)
print ("tamaño etiquetas entrenamiento gruesas: ", train_labels_coarse.shape)
print ("tamaño imagenes test: ",test_images.shape)
print ("tamaño etiquetas test finas: ", test_labels_fine.shape)
print ("tamaño etiquetas test gruesas: ", test_labels_coarse.shape)
# Out:
# tamaño imagenes entrenamiento:  (50000, 32, 32, 3)
# tamaño etiquetas entrenamiento finas:  (50000, 1)
# tamaño etiquetas entrenamiento gruesas:  (50000, 1)
# tamaño imagenes test:  (10000, 32, 32, 3)
# tamaño etiquetas test finas:  (10000, 1)
# tamaño etiquetas test gruesas:  (10000, 1)

# %% [markdown]
# Una vez obtenidos los datos, pasamos a observar una de las imagenes para hacernos a la idea de que tipo de imagenes son. Como hemos visto con la función "shape", las imagenes son de 32x32 pixeles y en color.
#
# Por otro lado, vamos a normalizar las imagenes para escalar los valores de los pixeles entre 0 y 1 en vez de 0 y 255 y así acotar el rango. A su vez, vamos a pasar todas las etiquetas a categóricas para poder utilizar el optimizador categorical_crossentropy.

# %%
#Normalizacion
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

#etiquetas a categóricas
train_labels_fine = to_categorical(train_labels_fine)
test_labels_fine = to_categorical(test_labels_fine)
train_labels_coarse = to_categorical(train_labels_coarse)
test_labels_coarse = to_categorical(test_labels_coarse)

print ("tamaño etiquetas entrenamiento finas: ", train_labels_fine.shape)
print ("tamaño etiquetas entrenamiento gruesas: ", train_labels_coarse.shape)
print ("tamaño etiquetas test finas: ", test_labels_fine.shape)
print ("tamaño etiquetas test gruesas: ", test_labels_coarse.shape)
# Out:
# tamaño etiquetas entrenamiento finas:  (50000, 100)
# tamaño etiquetas entrenamiento gruesas:  (50000, 20)
# tamaño etiquetas test finas:  (10000, 100)
# tamaño etiquetas test gruesas:  (10000, 20)

# %% [markdown]
# Vamos a ver como ejemplo una de las imagenes con sus respectivas etiquetas(estamos utilizando las funciones definidas en el primer apartado):

# %%
#Ejemplo
digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
print("Clase: ", obtener_clase(train_labels_fine[4]))
print("Superclase: ", obtener_superclase(train_labels_coarse[4]))
# Out:
# Clase:  aquarium fish
# Superclase:  fish

# %% [markdown]
# ### **MEZCLAR LAS IMÁGENES**

# %%
#Barajar los datos de entrenamiento
train_images, train_labels_fine, train_labels_coarse = shuffle(train_images, train_labels_fine, train_labels_coarse, random_state=42)

# Barajar los datos de prueba
test_images, test_labels_fine, test_labels_coarse = shuffle(test_images, test_labels_fine, test_labels_coarse, random_state=42)

# Visualizar una imagen después de barajar
digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()
print("Clase: ", obtener_clase(train_labels_fine[4]))
print("Superclase: ", obtener_superclase(train_labels_coarse[4]))
# Out:
# Clase:  seal
# Superclase:  aquatic mammals

# %% [markdown]
# **APARTADO 3:**
#
# dividir los datos de entrenamiento en dos conjuntos:
#
# *   Datos de entrenamiento: 40.000 datos
# *   Datos de validación: 10.000 datos

# %%
train_images_validation = train_images[10000:]
partial_train_images_validation = train_images[:10000]

train_labels_fine_validation = train_labels_fine[10000:]
partial_train_labels_fine_validation = train_labels_fine[:10000]

train_labels_coarse_validation = train_labels_coarse[10000:]
partial_train_labels_coarse_validation = train_labels_coarse[:10000]

print("Número de imágenes de entrenamiento:", len(train_images_validation))
print("Número de imágenes de validación:", len(partial_train_images_validation))
# Out:
# Número de imágenes de entrenamiento: 40000
# Número de imágenes de validación: 10000

# %% [markdown]
# ### **INGENIERÍA DE CARACTERÍSTICA**
# Vamos a tratar de aplicar filtros a las imagenes para intentar encontrar algún cambio que mejore las imagenes, ya que al tener muy baja resolución va a ser muy complicado que obtengamos valores de accuracy decentes.Para ello, vamos a aplicar varios kernels.

# %% [markdown]
# #### **Afilar imágenes:**
#
# Usamos un kernel para afilar las imágenes y conseguir que los bordes estén más detallados.

# %%
kernel_afilado = np.array([[0, -1, 0],
                          [-1, 5, -1],
                          [0, -1, 0]], dtype=np.float32)

# Seleccionar una imagen de tu conjunto de datos
imagen_original = train_images[1]

# Aplicar el filtro de afilado utilizando filter2D
imagen_afilada = cv2.filter2D(imagen_original, -1, kernel_afilado)

# Crear subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Mostrar la imagen original
axes[0].imshow(imagen_original, cmap=plt.cm.binary)
axes[0].set_title('Imagen Original')

# Mostrar la imagen afilada
axes[1].imshow(imagen_afilada, cmap=plt.cm.binary)
axes[1].set_title('Imagen Afilada')
plt.tight_layout()

plt.show()

#TODAS LAS IMAGENES
train_images_afiladas = []
test_images_afiladas = []

for imagen_original in train_images:

    imagen_procesada = cv2.filter2D(imagen_original, -1, kernel_afilado)
    train_images_afiladas.append(imagen_procesada)

for imagen_original in test_images:

    imagen_procesada = cv2.filter2D(imagen_original, -1, kernel_afilado)
    test_images_afiladas.append(imagen_procesada)

train_images_afiladas = np.array(train_images_afiladas)
test_images_afiladas = np.array(test_images_afiladas)

#comprobamos que el tamaño sigue siendo el mismo
print (train_images_afiladas.shape)
print (test_images_afiladas.shape)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# Se observa que las imagenes afiladas remarcan más los bordes de la figura, lo que puede ser una buena opción para que el modelo reconozca mejor ciertas características.

# %% [markdown]
# #### **Filtro Laplace:**
# También vamos a tratar de usar el filtro de Laplace, ya que es bastante usado para el reconocimiento de bordes, ya que las realza. La información sobre este filtro se ha obtenido de la siguiente página: https://pythoneyes.wordpress.com/2017/06/20/filtro-de-laplace-realce-de-bordes-en-imagenes-con-python-3/

# %%
# Definir el tamaño del kernel y los coeficientes
tamaño = (5, 5)
coeficientes = np.array([0, 0, -1, 0, 0, 0, -1, -2, -1, 0, -1, -2, 16, -2, -1, 0, -1, -2, -1, 0, 0, 0, -1, 0, 0], dtype=np.float32)
coeficientes = coeficientes.reshape((tamaño[0], tamaño[1]))  # Reorganizar la lista en una matriz 2D
factor = 1


# Seleccionar una imagen de tu conjunto de datos
imagen_original = train_images[1]

# Aplicar el filtro de Laplace utilizando filter2D
imagen_original_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)
imagen_lapl = cv2.filter2D(imagen_original_gris, -1, coeficientes * factor)
imagen_lapl = cv2.cvtColor(imagen_lapl, cv2.COLOR_GRAY2BGR)

# Crear subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Mostrar la imagen original
axes[0].imshow(imagen_original, cmap=plt.cm.binary)
axes[0].set_title('Imagen Original')

# Mostrar la imagen afilada
axes[1].imshow(imagen_lapl, cmap=plt.cm.binary)
axes[1].set_title('Imagen Laplace')
plt.tight_layout()

plt.show()

# Aplicar el filtro a todo el conjunto de imágenes
train_images_Lap = []

for imagen_original in train_images:
    # Convertir la imagen a escala de grises si es necesario
    if imagen_original.shape[-1] == 3:
        imagen_original_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)
    else:
        imagen_original_gris = imagen_original

    # Asegurarse de que la imagen original sea de tipo float32
    imagen_original_gris = imagen_original_gris.astype(np.float32)

    # Aplicar el filtro utilizando filter2D
    imagen_procesada_BYN = cv2.filter2D(imagen_original_gris, -1, coeficientes * factor)

    # Convertir la imagen procesada de nuevo a color si es necesario
    if imagen_original.shape[-1] == 3:
      imagen_bordes= cv2.cvtColor(imagen_procesada_BYN, cv2.COLOR_GRAY2BGR)

    # Agregar la imagen procesada a la lista
    train_images_Lap.append(imagen_bordes)

# Convertir la lista a un tensor numpy
train_images_Lap = np.array(train_images_Lap)



# Aplicar el filtro a todo el conjunto de imágenes
test_images_Lap = []

for imagen_original in test_images:
    # Convertir la imagen a escala de grises si es necesario
    if imagen_original.shape[-1] == 3:
        imagen_original_gris = cv2.cvtColor(imagen_original, cv2.COLOR_BGR2GRAY)
    else:
        imagen_original_gris = imagen_original

    # Asegurarse de que la imagen original sea de tipo float32
    imagen_original_gris = imagen_original_gris.astype(np.float32)

    # Aplicar el filtro utilizando filter2D
    imagen_procesada_BYN = cv2.filter2D(imagen_original_gris, -1, coeficientes * factor)

    # Convertir la imagen procesada de nuevo a color si es necesario
    if imagen_original.shape[-1] == 3:
      imagen_bordes = cv2.cvtColor(imagen_procesada_BYN, cv2.COLOR_GRAY2BGR)

    # Agregar la imagen procesada a la lista
    test_images_Lap.append(imagen_bordes)

# Convertir la lista a un tensor numpy
test_images_Lap = np.array(test_images_Lap)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Aumentar el tamaño de las imagenes (Interpolación)

# %%
scale_factor = 1.5

# Lista para almacenar las imágenes aumentadas
train_images_aumentadas = []

# Iterar sobre cada imagen en el conjunto de datos original
for img in train_images:
    # Aplicar la interpolación para aumentar el tamaño
    img_resized = cv2.resize(img, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_CUBIC)

    # Añadir la imagen aumentada a la lista
    train_images_aumentadas.append(img_resized)

# Convertir la lista de imágenes aumentadas a un tensor
train_images_aumentadas = np.array(train_images_aumentadas)


# Lista para almacenar las imágenes aumentadas
test_images_aumentadas = []

# Iterar sobre cada imagen en el conjunto de datos original
for img in test_images:
    # Aplicar la interpolación para aumentar el tamaño
    img_resized = cv2.resize(img, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_CUBIC)

    # Añadir la imagen aumentada a la lista
    test_images_aumentadas.append(img_resized)

# Convertir la lista de imágenes aumentadas a un tensor
test_images_aumentadas = np.array(test_images_aumentadas)

# Crear subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Mostrar la imagen original
axes[0].imshow(train_images[1], cmap=plt.cm.binary)
axes[0].set_title('Imagen Original')

# Mostrar la imagen afilada
axes[1].imshow(train_images_aumentadas[1], cmap=plt.cm.binary)
axes[1].set_title('Imagen Aumentada')
plt.tight_layout()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Hemos pasado de tener imagenes de 32x32 pixeles a 48x48, las cuales son claramente de mayor calidad, el problema es que aumentar las imagenes consume una gran cantidad de RAM, por lo que una vez las probemos, tendremos que analizar si merece la pena tanto consumo de recursos a cambio de un poco de mejora en la accuracy.

# %% [markdown]
# # **5.- DESARROLLO DE MODELOS MEJOR QUE EL DE REFERENCIA**

# %% [markdown]
# Necesitamos un modelo que acierte por lo menos un 1% de los casos, ya que tenemos 100 categorías diferentes, por lo que aleatoriamente ya se podría obtener ese 1%.

# %% [markdown]
# ### **MODELO DE REFRENCIA**
#
# Las capas fundamentales para poder realizar un modelo convolucional son las siguientes.
#
# *   1 capa convolucional
# *   1 capa de Max Pooling
# *   1 capa flatten
# *   2 capas Densas de salida
# Nota: utilizamos dos salidas para poder obtener la clase fina y la gruesa.

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3))(input_layer)
pol = MaxPooling2D(pool_size=(2, 2)) (conv)

flat = Flatten() (pol)

output_fine = Dense(100, activation='softmax', name='output_fine') (flat)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (flat)
model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='sgd',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

model.fit(train_images, {'output_fine': train_labels_fine, 'output_coarse': train_labels_coarse},
          epochs = 15,
          batch_size = 64,
          verbose = 1)

score = model.evaluate(test_images, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])
# Out:
# Epoch 1/15
# 782/782 [==============================] - 89s 113ms/step - loss: 7.0507 - output_fine_loss: 4.3387 - output_coarse_loss: 2.7121 - output_fine_accuracy: 0.0559 - output_coarse_accuracy: 0.1670
# Epoch 2/15
# 782/782 [==============================] - 87s 111ms/step - loss: 6.3940 - output_fine_loss: 3.8982 - output_coarse_loss: 2.4958 - output_fine_accuracy: 0.1232 - output_coarse_accuracy: 0.2342
# Epoch 3/15
# 782/782 [==============================] - 82s 105ms/step - loss: 6.1128 - output_fine_loss: 3.7091 - output_coarse_loss: 2.4037 - output_fine_accuracy: 0.1609 - output_coarse_accuracy: 0.2652
# Epoch 4/15
# 782/782 [==============================] - 83s 106ms/step - loss: 5.9055 - output_fine_loss: 3.5824 - output_coarse_loss: 2.3230 - output_fine_accuracy: 0.1829 - output_coarse_accuracy: 0.2933
# Epoch 5/15
# 782/782 [==============================] - 83s 106ms/step - loss: 5.7194 - output_fine_loss: 3.4731 - output_coarse_loss: 2.2463 - output_fine_accuracy: 0.2034 - output_coarse_accuracy: 0.3179
# Epoch 6/15
# 782/782 [==============================] - 83s 106ms/step - loss: 5.5378 - output_fine_loss: 3.3637 - output_coarse_loss: 2.1741 - output_fine_accuracy: 0.2251 - output_coarse_accuracy: 0.3410
# Epoch 7/15
# 782/782 [==============================] - 82s 104ms/step - loss: 5.3657 - output_fine_loss: 3.2539 - output_coarse_loss: 2.1118 - output_fine_accuracy: 0.2478 - output_coarse_accuracy: 0.3589
# Epoch 8/15
# 782/782 [==============================] - 85s 108ms/step - loss: 5.2098 - output_fine_loss: 3.1483 - output_coarse_loss: 2.0615 - output_fine_accuracy: 0.2668 - output_coarse_accuracy: 0.3748
# Epoch 9/15
# 782/782 [==============================] - 83s 106ms/step - loss: 5.0610 - output_fine_loss: 3.0451 - output_coarse_loss: 2.0159 - output_fine_accuracy: 0.2873 - output_coarse_accuracy: 0.3894
# Epoch 10/15
# 782/782 [==============================] - 81s 104ms/step - loss: 4.9262 - output_fine_loss: 2.9488 - output_coarse_loss: 1.9774 - output_fine_accuracy: 0.3058 - output_coarse_accuracy: 0.4015
# Epoch 11/15
# 782/782 [==============================] - 83s 106ms/step - loss: 4.8106 - output_fine_loss: 2.8634 - output_coarse_loss: 1.9471 - output_fine_accuracy: 0.3234 - output_coarse_accuracy: 0.4115
# Epoch 12/15
# 782/782 [==============================] - 82s 104ms/step - loss: 4.7044 - output_fine_loss: 2.7839 - output_coarse_loss: 1.9205 - output_fine_accuracy: 0.3390 - output_coarse_accuracy: 0.4191
# Epoch 13/15
# 782/782 [==============================] - 89s 114ms/step - loss: 4.6099 - output_fine_loss: 2.7135 - output_coarse_loss: 1.8964 - output_fine_accuracy: 0.3519 - output_coarse_accuracy: 0.4264
# Epoch 14/15
# 782/782 [==============================] - 84s 108ms/step - loss: 4.5272 - output_fine_loss: 2.6514 - output_coarse_loss: 1.8758 - output_fine_accuracy: 0.3651 - output_coarse_accuracy: 0.4343
# Epoch 15/15
# 782/782 [==============================] - 84s 108ms/step - loss: 4.4512 - output_fine_loss: 2.5948 - output_coarse_loss: 1.8564 - output_fine_accuracy: 0.3776 - output_coarse_accuracy: 0.4385
# 313/313 [==============================] - 5s 16ms/step - loss: 4.9392 - output_fine_loss: 2.9078 - output_coarse_loss: 2.0313 - output_fine_accuracy: 0.3106 - output_coarse_accuracy: 0.3881
# Precisión en el conjunto de prueba (Clasificación Fina): 0.31060001254081726
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.3880999982357025

# %% [markdown]
# ### **PRECISIÓN APROXIMADA** = 30.51 %
#
# A partir de la precisión del modelo de referencia empezaremos a trabajar. Todos los modelos que devueleva una precisión inferior al **30.5%** los descartamos directamente. Es importante destacar que la precisión en las clases gruesas es mayor (como era de esperar, por el número de clases que hay)

# %% [markdown]
# ### **MODELO CON LAS IMÁGENES AFILADAS:**
# *   1 Capa Convolucional
# *   1 capa de Max Pooling
# *   1 capa Flatten
# *   2 capas Densas de salida

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3))(input_layer)
pol = MaxPooling2D(pool_size=(2, 2)) (conv)

flat = Flatten() (pol)

output_fine = Dense(100, activation='softmax', name='output_fine') (flat)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (flat)
model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='sgd',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

model.fit(train_images_afiladas, {'output_fine': train_labels_fine, 'output_coarse': train_labels_coarse},
          epochs = 15,
          batch_size = 64,
          verbose = 1)

score = model.evaluate(test_images_afiladas, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])
# Out:
# Epoch 1/15
# 782/782 [==============================] - 107s 135ms/step - loss: 6.9620 - output_fine_loss: 4.3025 - output_coarse_loss: 2.6595 - output_fine_accuracy: 0.0665 - output_coarse_accuracy: 0.1936
# Epoch 2/15
# 782/782 [==============================] - 87s 111ms/step - loss: 6.0248 - output_fine_loss: 3.7051 - output_coarse_loss: 2.3197 - output_fine_accuracy: 0.1650 - output_coarse_accuracy: 0.2978
# Epoch 3/15
# 782/782 [==============================] - 85s 108ms/step - loss: 5.4637 - output_fine_loss: 3.3393 - output_coarse_loss: 2.1243 - output_fine_accuracy: 0.2353 - output_coarse_accuracy: 0.3561
# Epoch 4/15
# 782/782 [==============================] - 84s 107ms/step - loss: 5.0366 - output_fine_loss: 3.0519 - output_coarse_loss: 1.9847 - output_fine_accuracy: 0.2889 - output_coarse_accuracy: 0.4026
# Epoch 5/15
# 782/782 [==============================] - 83s 106ms/step - loss: 4.7043 - output_fine_loss: 2.8249 - output_coarse_loss: 1.8793 - output_fine_accuracy: 0.3323 - output_coarse_accuracy: 0.4333
# Epoch 6/15
# 782/782 [==============================] - 83s 107ms/step - loss: 4.4375 - output_fine_loss: 2.6369 - output_coarse_loss: 1.8005 - output_fine_accuracy: 0.3704 - output_coarse_accuracy: 0.4547
# Epoch 7/15
# 782/782 [==============================] - 84s 108ms/step - loss: 4.2099 - output_fine_loss: 2.4749 - output_coarse_loss: 1.7350 - output_fine_accuracy: 0.4041 - output_coarse_accuracy: 0.4738
# Epoch 8/15
# 782/782 [==============================] - 83s 107ms/step - loss: 4.0114 - output_fine_loss: 2.3319 - output_coarse_loss: 1.6795 - output_fine_accuracy: 0.4351 - output_coarse_accuracy: 0.4903
# Epoch 9/15
# 782/782 [==============================] - 81s 104ms/step - loss: 3.8365 - output_fine_loss: 2.2043 - output_coarse_loss: 1.6322 - output_fine_accuracy: 0.4638 - output_coarse_accuracy: 0.5068
# Epoch 10/15
# 782/782 [==============================] - 83s 106ms/step - loss: 3.6767 - output_fine_loss: 2.0882 - output_coarse_loss: 1.5884 - output_fine_accuracy: 0.4931 - output_coarse_accuracy: 0.5173
# Epoch 11/15
# 782/782 [==============================] - 82s 104ms/step - loss: 3.5309 - output_fine_loss: 1.9827 - output_coarse_loss: 1.5482 - output_fine_accuracy: 0.5155 - output_coarse_accuracy: 0.5306
# Epoch 12/15
# 782/782 [==============================] - 83s 107ms/step - loss: 3.3960 - output_fine_loss: 1.8829 - output_coarse_loss: 1.5131 - output_fine_accuracy: 0.5367 - output_coarse_accuracy: 0.5382
# Epoch 13/15
# 782/782 [==============================] - 81s 104ms/step - loss: 3.2674 - output_fine_loss: 1.7917 - output_coarse_loss: 1.4757 - output_fine_accuracy: 0.5589 - output_coarse_accuracy: 0.5489
# Epoch 14/15
# 782/782 [==============================] - 82s 104ms/step - loss: 3.1486 - output_fine_loss: 1.7050 - output_coarse_loss: 1.4436 - output_fine_accuracy: 0.5821 - output_coarse_accuracy: 0.5580
# Epoch 15/15
# 782/782 [==============================] - 82s 104ms/step - loss: 3.0294 - output_fine_loss: 1.6212 - output_coarse_loss: 1.4083 - output_fine_accuracy: 0.6012 - output_coarse_accuracy: 0.5689
# 313/313 [==============================] - 5s 16ms/step - loss: 5.0537 - output_fine_loss: 2.8252 - output_coarse_loss: 2.2286 - output_fine_accuracy: 0.3408 - output_coarse_accuracy: 0.3959
# Precisión en el conjunto de prueba (Clasificación Fina): 0.3407999873161316
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.39590001106262207

# %% [markdown]
# ### **precisión aproximada** = *32.28* %
# Las imágenes afiladas funcionan mejor que las imágeness originales.

# %% [markdown]
# ### **MODELO CON LAS IMÁGENES CON BORDES RESALTADOS (LAPLACE):**

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3))(input_layer)
pol = MaxPooling2D(pool_size=(2, 2)) (conv)

flat = Flatten() (pol)

output_fine = Dense(100, activation='softmax', name='output_fine') (flat)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (flat)
model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='sgd',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

model.fit(train_images_Lap, {'output_fine': train_labels_fine, 'output_coarse': train_labels_coarse},
          epochs = 15,
          batch_size = 64,
          verbose = 1)

score = model.evaluate(test_images_Lap, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])
# Out:
# Epoch 1/15
# 782/782 [==============================] - 83s 104ms/step - loss: 7.0423 - output_fine_loss: 4.3240 - output_coarse_loss: 2.7182 - output_fine_accuracy: 0.0727 - output_coarse_accuracy: 0.1868
# Epoch 2/15
# 782/782 [==============================] - 83s 107ms/step - loss: 6.0539 - output_fine_loss: 3.6844 - output_coarse_loss: 2.3696 - output_fine_accuracy: 0.1845 - output_coarse_accuracy: 0.3022
# Epoch 3/15
# 782/782 [==============================] - 81s 103ms/step - loss: 5.5123 - output_fine_loss: 3.2570 - output_coarse_loss: 2.2553 - output_fine_accuracy: 0.2586 - output_coarse_accuracy: 0.3346
# Epoch 4/15
# 782/782 [==============================] - 83s 106ms/step - loss: 5.1455 - output_fine_loss: 2.9711 - output_coarse_loss: 2.1744 - output_fine_accuracy: 0.3127 - output_coarse_accuracy: 0.3608
# Epoch 5/15
# 782/782 [==============================] - 81s 103ms/step - loss: 4.8701 - output_fine_loss: 2.7563 - output_coarse_loss: 2.1137 - output_fine_accuracy: 0.3530 - output_coarse_accuracy: 0.3782
# Epoch 6/15
# 782/782 [==============================] - 81s 104ms/step - loss: 4.6448 - output_fine_loss: 2.5769 - output_coarse_loss: 2.0680 - output_fine_accuracy: 0.3921 - output_coarse_accuracy: 0.3924
# Epoch 7/15
# 782/782 [==============================] - 81s 104ms/step - loss: 4.4322 - output_fine_loss: 2.4179 - output_coarse_loss: 2.0143 - output_fine_accuracy: 0.4242 - output_coarse_accuracy: 0.4076
# Epoch 8/15
# 782/782 [==============================] - 80s 102ms/step - loss: 4.2410 - output_fine_loss: 2.2729 - output_coarse_loss: 1.9682 - output_fine_accuracy: 0.4565 - output_coarse_accuracy: 0.4198
# Epoch 9/15
# 782/782 [==============================] - 82s 105ms/step - loss: 4.0817 - output_fine_loss: 2.1385 - output_coarse_loss: 1.9432 - output_fine_accuracy: 0.4866 - output_coarse_accuracy: 0.4294
# Epoch 10/15
# 782/782 [==============================] - 80s 103ms/step - loss: 3.9041 - output_fine_loss: 2.0081 - output_coarse_loss: 1.8960 - output_fine_accuracy: 0.5183 - output_coarse_accuracy: 0.4447
# Epoch 11/15
# 782/782 [==============================] - 82s 105ms/step - loss: 3.7495 - output_fine_loss: 1.8873 - output_coarse_loss: 1.8622 - output_fine_accuracy: 0.5455 - output_coarse_accuracy: 0.4542
# Epoch 12/15
# 782/782 [==============================] - 80s 102ms/step - loss: 3.6068 - output_fine_loss: 1.7689 - output_coarse_loss: 1.8379 - output_fine_accuracy: 0.5739 - output_coarse_accuracy: 0.4661
# Epoch 13/15
# 782/782 [==============================] - 80s 103ms/step - loss: 3.4527 - output_fine_loss: 1.6509 - output_coarse_loss: 1.8017 - output_fine_accuracy: 0.6050 - output_coarse_accuracy: 0.4753
# Epoch 14/15
# 782/782 [==============================] - 81s 104ms/step - loss: 3.3179 - output_fine_loss: 1.5375 - output_coarse_loss: 1.7804 - output_fine_accuracy: 0.6337 - output_coarse_accuracy: 0.4856
# Epoch 15/15
# 782/782 [==============================] - 80s 103ms/step - loss: 3.1765 - output_fine_loss: 1.4331 - output_coarse_loss: 1.7434 - output_fine_accuracy: 0.6607 - output_coarse_accuracy: 0.4977
# 313/313 [==============================] - 5s 16ms/step - loss: 8.6758 - output_fine_loss: 4.1200 - output_coarse_loss: 4.5557 - output_fine_accuracy: 0.2140 - output_coarse_accuracy: 0.1965
# Precisión en el conjunto de prueba (Clasificación Fina): 0.21400000154972076
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.1965000033378601

# %% [markdown]
# ### **precisión aproximada** = *21.85* %
#
# Las imágenes con Bordes Resaltados **no** son más eficientes que las imágenes orginales, por lo que no las usaremos.

# %% [markdown]
# ### Modelo con las imagenes aumentadas:
#
# Para este modelo hemos tenido que reducir el número de épocas y aumentar el bach-size, asi como eliminar la salida de la clase gruesa, porque consume demasiados recursos.

# %%
input_layer = Input(shape=(48, 48, 3))

conv = Conv2D(128, (3, 3), activation='relu', input_shape=(48, 48, 3))(input_layer)
pol = MaxPooling2D(pool_size=(2, 2)) (conv)

flat = Flatten() (pol)

dense = Dense(512, activation='relu') (flat)

output_fine = Dense(100, activation='softmax', name='output_fine') (dense)
model = Model(inputs=input_layer, outputs=output_fine)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(train_images_aumentadas, train_labels_fine,
          epochs = 15,
          batch_size = 200,
          verbose = 1)

score = model.evaluate(test_images_aumentadas, test_labels_fine )
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[1])
# Out:
# Epoch 1/15
# 250/250 [==============================] - 683s 3s/step - loss: 3.6980 - accuracy: 0.1559
# Epoch 2/15
# 250/250 [==============================] - 698s 3s/step - loss: 2.8129 - accuracy: 0.3130
# Epoch 3/15
# 250/250 [==============================] - 685s 3s/step - loss: 2.4083 - accuracy: 0.3935
# Epoch 4/15
# 250/250 [==============================] - 697s 3s/step - loss: 2.0768 - accuracy: 0.4663
# Epoch 5/15
# 250/250 [==============================] - 687s 3s/step - loss: 1.7519 - accuracy: 0.5423
# Epoch 6/15
# 250/250 [==============================] - 714s 3s/step - loss: 1.4417 - accuracy: 0.6194
# Epoch 7/15
# 250/250 [==============================] - 715s 3s/step - loss: 1.1321 - accuracy: 0.6995
# Epoch 8/15
# 250/250 [==============================] - 711s 3s/step - loss: 0.8708 - accuracy: 0.7704
# Epoch 9/15
# 250/250 [==============================] - 714s 3s/step - loss: 0.6468 - accuracy: 0.8329
# Epoch 10/15
# 250/250 [==============================] - 711s 3s/step - loss: 0.4589 - accuracy: 0.8867
# Epoch 11/15
# 250/250 [==============================] - 709s 3s/step - loss: 0.3210 - accuracy: 0.9259
# Epoch 12/15
# 250/250 [==============================] - 708s 3s/step - loss: 0.2368 - accuracy: 0.9467
# Epoch 13/15
# 250/250 [==============================] - 709s 3s/step - loss: 0.1738 - accuracy: 0.9630
# Epoch 14/15
# 250/250 [==============================] - 717s 3s/step - loss: 0.1312 - accuracy: 0.9733
# Epoch 15/15
# 250/250 [==============================] - 715s 3s/step - loss: 0.1181 - accuracy: 0.9755
# 313/313 [==============================] - 37s 117ms/step - loss: 5.2776 - accuracy: 0.3192
# Precisión en el conjunto de prueba (Clasificación Fina): 0.3192000091075897

# %% [markdown]
# Llegamos a la conclusión de que la mejora no es lo suficientemente significativa como para utilizar estas imagenes, ya que no disponemos de los recursos necesarios. Si se hubiera podido, probablemente aumentar las imagenes a un tamaño 64x64 habría aumentado la accuracy.
# Cabe destacar que el modelo se entrena más facilmente y es capaz de alcanzar una mayor precisión más rápido.

# %% [markdown]
# # **6.- DESARROLLO DE UN MODELO CON SOBREAJUSTE**

# %%
# Configurar el callback EarlyStopping para detener el entrenamiento si la pérdida en val_loss no mejora durante 5 épocas consecutivas
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",
                                                  patience=5)  # Si val_loss no disminuye durante 5 épocas consecutivas, se detiene el entrenamiento

# %% [markdown]
# ### **MODELO MULTICAPA CON IMÁGENES AFILADAS:**
#
#
# Vamos a aumentar el número de capas convolucionales para encontrar un modelo que sea capaz de obtener mucha más precisión. Las capas van a ser las siguientes:
#
# *   2 Capas Convolucionales(32, (3,3))
# *   1 Capa Max Pooling
# *   2 Capas Convolucionales(64, (3,3))
# *   1 Capa Max Pooling
# *   2 Capas Convolucionales(128, (3,3))
# *   1 Capa Max Pooling
#
# Es importante mencionar que a este modelo se le podrían añadir muchas capas más y esto aumentaría la potencia, pero para ello se requieren unos recursos de los que no disponemos. Ya con este tipo de modelo nos podemos hacer una idea de como debe ser. Recordemos que después de una capa convolucional suele ser necesario una de pooling. También introducimos capas densas para aumentar el número de parametros.
#
# https://www.kaggle.com/code/diaaessam/alexnet-for-cifar-100 en este proyecto podemos ver como se puede crear una buena arquitectura, más compleja. Las capas convolucionales permiten aprender jerarquías de características en una imagen. Capas más profundas pueden capturar patrones de mayor complejidad y abstracción, permitiendo que el modelo represente conceptos más sofisticados. https://github.com/Sripriya07/CIFAR-100/blob/master/cifar100.py en este otro proyecto también podemos como crear una arquitectura multicapa compleja.

# %% [markdown]
# Por otro lado, vamos a hacer la separación de los datos de entrenamiento en dos conjuntos, para utilizar la validación hold- out.

# %%
train_images_validation = train_images_afiladas[10000:]
partial_train_images_validation = train_images_afiladas[:10000]

print(len(train_images_validation))
print(len(partial_train_images_validation))

train_labels_fine_validation = train_labels_fine[10000:]
partial_train_labels_fine_validation = train_labels_fine[:10000]

train_labels_coarse_validation = train_labels_coarse[10000:]
partial_train_labels_coarse_validation = train_labels_coarse[:10000]
# Out:
# 40000
# 10000

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(32, (3, 3), activation='relu', padding = 'same', input_shape=(32, 32, 3))(input_layer)
conv2 = Conv2D(32, (3, 3), activation='relu', padding = 'same') (conv)
pol = MaxPooling2D(pool_size=(2, 2)) (conv2)


conv3 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (pol)
conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (conv3)
pol2 = MaxPooling2D(pool_size=(2, 2)) (conv4)

conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(pol2)
conv6 = Conv2D(128, (3, 3), activation='relu', padding = 'same') (conv5)
pol3 = MaxPooling2D(pool_size=(2, 2)) (conv6)

flat = Flatten() (pol3)
dense = Dense(512, activation='relu') (flat)
dense1 = Dense(128, activation='relu') (dense)

output_fine = Dense(100, activation='softmax', name='output_fine') (dense1)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (dense1)

model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='Adam',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

history = model.fit(train_images_validation, {'output_fine': train_labels_fine_validation, 'output_coarse': train_labels_coarse_validation},
          epochs = 50,
          batch_size = 128,
          validation_data = (partial_train_images_validation, {'output_fine': partial_train_labels_fine_validation, 'output_coarse': partial_train_labels_coarse_validation}),
          verbose = 1)


score = model.evaluate(test_images_afiladas, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])

# Graficamos la pérdida y la precisión.
history_dict = history.history
history_dict.keys()

output_fine_loss = history.history['output_fine_loss']
val_output_fine_loss = history.history['val_output_fine_loss']


epochs = range(1, len(output_fine_loss) + 1)

valor_minimo = min(val_output_fine_loss)
posicion_minimo = val_output_fine_loss.index(valor_minimo)
print("Valor mínimo:", valor_minimo)
print("Posición del valor mínimo:", posicion_minimo)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_loss, 'bo', label='Pérdida de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_loss, 'b', label='Pérdida de Validación (fine)')
plt.title('Pérdida de Entrenamiento y Validación [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine Loss')
plt.legend()

plt.show()

output_fine_accuracy = history.history['output_fine_accuracy']
val_output_fine_accuracy = history.history['val_output_fine_accuracy']

valor_maximo = max(val_output_fine_accuracy)
posicion_maximo = val_output_fine_accuracy.index(valor_maximo)
print("Valor máximo:", valor_maximo)
print("Posición del valor máximo:", posicion_maximo)

valor_maximo_entrenamiento = max(output_fine_accuracy)
posicion_maximo_entrenamiento = output_fine_accuracy.index(valor_maximo_entrenamiento)
print("Valor máximo (entrenamiento):", valor_maximo_entrenamiento)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_accuracy, 'bo', label='Precisión de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_accuracy, 'b', label='Precisión de Validación (fine)')
plt.title('Precisión de Entrenamiento y Valización [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 313/313 [==============================] - 392s 1s/step - loss: 6.6931 - output_fine_loss: 4.1064 - output_coarse_loss: 2.5867 - output_fine_accuracy: 0.0694 - output_coarse_accuracy: 0.1962 - val_loss: 5.9288 - val_output_fine_loss: 3.6583 - val_output_coarse_loss: 2.2705 - val_output_fine_accuracy: 0.1237 - val_output_coarse_accuracy: 0.3015
# Epoch 2/50
# 313/313 [==============================] - 388s 1s/step - loss: 5.4172 - output_fine_loss: 3.3413 - output_coarse_loss: 2.0759 - output_fine_accuracy: 0.1835 - output_coarse_accuracy: 0.3505 - val_loss: 5.0883 - val_output_fine_loss: 3.1288 - val_output_coarse_loss: 1.9596 - val_output_fine_accuracy: 0.2196 - val_output_coarse_accuracy: 0.3847
# Epoch 3/50
# 313/313 [==============================] - 416s 1s/step - loss: 4.5823 - output_fine_loss: 2.8320 - output_coarse_loss: 1.7503 - output_fine_accuracy: 0.2764 - output_coarse_accuracy: 0.4493 - val_loss: 4.3281 - val_output_fine_loss: 2.6773 - val_output_coarse_loss: 1.6508 - val_output_fine_accuracy: 0.3106 - val_output_coarse_accuracy: 0.4834
# Epoch 4/50
# 313/313 [==============================] - 397s 1s/step - loss: 3.9543 - output_fine_loss: 2.4483 - output_coarse_loss: 1.5060 - output_fine_accuracy: 0.3554 - output_coarse_accuracy: 0.5216 - val_loss: 3.9593 - val_output_fine_loss: 2.4463 - val_output_coarse_loss: 1.5130 - val_output_fine_accuracy: 0.3572 - val_output_coarse_accuracy: 0.5196
# Epoch 5/50
# 313/313 [==============================] - 396s 1s/step - loss: 3.4808 - output_fine_loss: 2.1591 - output_coarse_loss: 1.3217 - output_fine_accuracy: 0.4158 - output_coarse_accuracy: 0.5748 - val_loss: 3.8078 - val_output_fine_loss: 2.3519 - val_output_coarse_loss: 1.4559 - val_output_fine_accuracy: 0.3826 - val_output_coarse_accuracy: 0.5413
# Epoch 6/50
# 313/313 [==============================] - 402s 1s/step - loss: 3.0760 - output_fine_loss: 1.9162 - output_coarse_loss: 1.1598 - output_fine_accuracy: 0.4707 - output_coarse_accuracy: 0.6240 - val_loss: 3.7167 - val_output_fine_loss: 2.2897 - val_output_coarse_loss: 1.4270 - val_output_fine_accuracy: 0.4065 - val_output_coarse_accuracy: 0.5578
# Epoch 7/50
# 313/313 [==============================] - 404s 1s/step - loss: 2.7044 - output_fine_loss: 1.6986 - output_coarse_loss: 1.0058 - output_fine_accuracy: 0.5211 - output_coarse_accuracy: 0.6726 - val_loss: 3.7113 - val_output_fine_loss: 2.2769 - val_output_coarse_loss: 1.4344 - val_output_fine_accuracy: 0.4081 - val_output_coarse_accuracy: 0.5630
# Epoch 8/50
# 313/313 [==============================] - 400s 1s/step - loss: 2.2898 - output_fine_loss: 1.4548 - output_coarse_loss: 0.8350 - output_fine_accuracy: 0.5774 - output_coarse_accuracy: 0.7254 - val_loss: 4.0098 - val_output_fine_loss: 2.4432 - val_output_coarse_loss: 1.5666 - val_output_fine_accuracy: 0.3992 - val_output_coarse_accuracy: 0.5516
# Epoch 9/50
# 313/313 [==============================] - 400s 1s/step - loss: 1.9325 - output_fine_loss: 1.2468 - output_coarse_loss: 0.6857 - output_fine_accuracy: 0.6281 - output_coarse_accuracy: 0.7728 - val_loss: 4.0267 - val_output_fine_loss: 2.4489 - val_output_coarse_loss: 1.5778 - val_output_fine_accuracy: 0.4144 - val_output_coarse_accuracy: 0.5694
# Epoch 10/50
# 313/313 [==============================] - 419s 1s/step - loss: 1.5876 - output_fine_loss: 1.0403 - output_coarse_loss: 0.5473 - output_fine_accuracy: 0.6808 - output_coarse_accuracy: 0.8170 - val_loss: 4.3419 - val_output_fine_loss: 2.6164 - val_output_coarse_loss: 1.7255 - val_output_fine_accuracy: 0.4168 - val_output_coarse_accuracy: 0.5688
# Epoch 11/50
# 313/313 [==============================] - 400s 1s/step - loss: 1.2740 - output_fine_loss: 0.8501 - output_coarse_loss: 0.4240 - output_fine_accuracy: 0.7304 - output_coarse_accuracy: 0.8569 - val_loss: 4.7404 - val_output_fine_loss: 2.8635 - val_output_coarse_loss: 1.8769 - val_output_fine_accuracy: 0.4037 - val_output_coarse_accuracy: 0.5654
# Epoch 12/50
# 313/313 [==============================] - 399s 1s/step - loss: 1.0127 - output_fine_loss: 0.6907 - output_coarse_loss: 0.3220 - output_fine_accuracy: 0.7765 - output_coarse_accuracy: 0.8902 - val_loss: 5.4129 - val_output_fine_loss: 3.2044 - val_output_coarse_loss: 2.2084 - val_output_fine_accuracy: 0.4033 - val_output_coarse_accuracy: 0.5577
# Epoch 13/50
# 313/313 [==============================] - 421s 1s/step - loss: 0.8606 - output_fine_loss: 0.5864 - output_coarse_loss: 0.2743 - output_fine_accuracy: 0.8070 - output_coarse_accuracy: 0.9059 - val_loss: 5.7484 - val_output_fine_loss: 3.3888 - val_output_coarse_loss: 2.3597 - val_output_fine_accuracy: 0.4012 - val_output_coarse_accuracy: 0.5590
# Epoch 14/50
# 313/313 [==============================] - 401s 1s/step - loss: 0.6911 - output_fine_loss: 0.4748 - output_coarse_loss: 0.2163 - output_fine_accuracy: 0.8409 - output_coarse_accuracy: 0.9258 - val_loss: 6.0644 - val_output_fine_loss: 3.5886 - val_output_coarse_loss: 2.4758 - val_output_fine_accuracy: 0.3968 - val_output_coarse_accuracy: 0.5584
# Epoch 15/50
# 313/313 [==============================] - 401s 1s/step - loss: 0.5746 - output_fine_loss: 0.3971 - output_coarse_loss: 0.1774 - output_fine_accuracy: 0.8643 - output_coarse_accuracy: 0.9391 - val_loss: 6.8195 - val_output_fine_loss: 4.0135 - val_output_coarse_loss: 2.8061 - val_output_fine_accuracy: 0.4018 - val_output_coarse_accuracy: 0.5572
# Epoch 16/50
# 313/313 [==============================] - 422s 1s/step - loss: 0.5179 - output_fine_loss: 0.3558 - output_coarse_loss: 0.1621 - output_fine_accuracy: 0.8784 - output_coarse_accuracy: 0.9458 - val_loss: 7.4924 - val_output_fine_loss: 4.3975 - val_output_coarse_loss: 3.0949 - val_output_fine_accuracy: 0.3936 - val_output_coarse_accuracy: 0.5568
# Epoch 17/50
# 313/313 [==============================] - 403s 1s/step - loss: 0.4518 - output_fine_loss: 0.3060 - output_coarse_loss: 0.1457 - output_fine_accuracy: 0.8959 - output_coarse_accuracy: 0.9502 - val_loss: 7.7662 - val_output_fine_loss: 4.5750 - val_output_coarse_loss: 3.1911 - val_output_fine_accuracy: 0.3954 - val_output_coarse_accuracy: 0.5569
# Epoch 18/50
# 313/313 [==============================] - 405s 1s/step - loss: 0.4328 - output_fine_loss: 0.2909 - output_coarse_loss: 0.1419 - output_fine_accuracy: 0.9024 - output_coarse_accuracy: 0.9517 - val_loss: 8.2506 - val_output_fine_loss: 4.8923 - val_output_coarse_loss: 3.3583 - val_output_fine_accuracy: 0.3936 - val_output_coarse_accuracy: 0.5564
# Epoch 19/50
# 313/313 [==============================] - 418s 1s/step - loss: 0.4058 - output_fine_loss: 0.2709 - output_coarse_loss: 0.1349 - output_fine_accuracy: 0.9078 - output_coarse_accuracy: 0.9552 - val_loss: 7.9938 - val_output_fine_loss: 4.7157 - val_output_coarse_loss: 3.2781 - val_output_fine_accuracy: 0.3940 - val_output_coarse_accuracy: 0.5564
# Epoch 20/50
# 313/313 [==============================] - 426s 1s/step - loss: 0.4090 - output_fine_loss: 0.2642 - output_coarse_loss: 0.1448 - output_fine_accuracy: 0.9122 - output_coarse_accuracy: 0.9522 - val_loss: 8.4443 - val_output_fine_loss: 5.0052 - val_output_coarse_loss: 3.4392 - val_output_fine_accuracy: 0.3921 - val_output_coarse_accuracy: 0.5547
# Epoch 21/50
# 313/313 [==============================] - 423s 1s/step - loss: 0.3552 - output_fine_loss: 0.2312 - output_coarse_loss: 0.1240 - output_fine_accuracy: 0.9224 - output_coarse_accuracy: 0.9591 - val_loss: 8.6050 - val_output_fine_loss: 5.0929 - val_output_coarse_loss: 3.5121 - val_output_fine_accuracy: 0.4006 - val_output_coarse_accuracy: 0.5564
# Epoch 22/50
# 313/313 [==============================] - 402s 1s/step - loss: 0.3211 - output_fine_loss: 0.2077 - output_coarse_loss: 0.1134 - output_fine_accuracy: 0.9320 - output_coarse_accuracy: 0.9632 - val_loss: 9.3363 - val_output_fine_loss: 5.5388 - val_output_coarse_loss: 3.7975 - val_output_fine_accuracy: 0.3900 - val_output_coarse_accuracy: 0.5455
# Epoch 23/50
# 313/313 [==============================] - 411s 1s/step - loss: 0.3116 - output_fine_loss: 0.2004 - output_coarse_loss: 0.1113 - output_fine_accuracy: 0.9332 - output_coarse_accuracy: 0.9635 - val_loss: 9.3585 - val_output_fine_loss: 5.6021 - val_output_coarse_loss: 3.7564 - val_output_fine_accuracy: 0.3919 - val_output_coarse_accuracy: 0.5514
# Epoch 24/50
# 313/313 [==============================] - 428s 1s/step - loss: 0.3121 - output_fine_loss: 0.2011 - output_coarse_loss: 0.1111 - output_fine_accuracy: 0.9341 - output_coarse_accuracy: 0.9634 - val_loss: 9.4877 - val_output_fine_loss: 5.6752 - val_output_coarse_loss: 3.8125 - val_output_fine_accuracy: 0.3905 - val_output_coarse_accuracy: 0.5501
# Epoch 25/50
# 313/313 [==============================] - 410s 1s/step - loss: 0.3112 - output_fine_loss: 0.1981 - output_coarse_loss: 0.1131 - output_fine_accuracy: 0.9340 - output_coarse_accuracy: 0.9640 - val_loss: 9.1359 - val_output_fine_loss: 5.5017 - val_output_coarse_loss: 3.6343 - val_output_fine_accuracy: 0.3948 - val_output_coarse_accuracy: 0.5479
# Epoch 26/50
# 313/313 [==============================] - 389s 1s/step - loss: 0.2946 - output_fine_loss: 0.1827 - output_coarse_loss: 0.1119 - output_fine_accuracy: 0.9416 - output_coarse_accuracy: 0.9646 - val_loss: 9.9301 - val_output_fine_loss: 5.9408 - val_output_coarse_loss: 3.9893 - val_output_fine_accuracy: 0.3903 - val_output_coarse_accuracy: 0.5470
# Epoch 27/50
# 313/313 [==============================] - 384s 1s/step - loss: 0.2542 - output_fine_loss: 0.1603 - output_coarse_loss: 0.0939 - output_fine_accuracy: 0.9474 - output_coarse_accuracy: 0.9692 - val_loss: 9.9038 - val_output_fine_loss: 5.9843 - val_output_coarse_loss: 3.9195 - val_output_fine_accuracy: 0.3908 - val_output_coarse_accuracy: 0.5484
# Epoch 28/50
# 313/313 [==============================] - 382s 1s/step - loss: 0.3010 - output_fine_loss: 0.1885 - output_coarse_loss: 0.1125 - output_fine_accuracy: 0.9390 - output_coarse_accuracy: 0.9639 - val_loss: 9.7735 - val_output_fine_loss: 5.9255 - val_output_coarse_loss: 3.8479 - val_output_fine_accuracy: 0.3868 - val_output_coarse_accuracy: 0.5503
# Epoch 29/50
# 313/313 [==============================] - 407s 1s/step - loss: 0.3031 - output_fine_loss: 0.1861 - output_coarse_loss: 0.1170 - output_fine_accuracy: 0.9391 - output_coarse_accuracy: 0.9636 - val_loss: 10.0494 - val_output_fine_loss: 6.0997 - val_output_coarse_loss: 3.9497 - val_output_fine_accuracy: 0.3790 - val_output_coarse_accuracy: 0.5403
# Epoch 30/50
# 313/313 [==============================] - 383s 1s/step - loss: 0.2851 - output_fine_loss: 0.1778 - output_coarse_loss: 0.1072 - output_fine_accuracy: 0.9423 - output_coarse_accuracy: 0.9658 - val_loss: 10.5036 - val_output_fine_loss: 6.4612 - val_output_coarse_loss: 4.0424 - val_output_fine_accuracy: 0.3891 - val_output_coarse_accuracy: 0.5499
# Epoch 31/50
# 313/313 [==============================] - 382s 1s/step - loss: 0.2546 - output_fine_loss: 0.1636 - output_coarse_loss: 0.0910 - output_fine_accuracy: 0.9469 - output_coarse_accuracy: 0.9688 - val_loss: 11.4381 - val_output_fine_loss: 6.9759 - val_output_coarse_loss: 4.4622 - val_output_fine_accuracy: 0.3926 - val_output_coarse_accuracy: 0.5433
# Epoch 32/50
# 313/313 [==============================] - 384s 1s/step - loss: 0.2399 - output_fine_loss: 0.1500 - output_coarse_loss: 0.0899 - output_fine_accuracy: 0.9502 - output_coarse_accuracy: 0.9708 - val_loss: 10.8321 - val_output_fine_loss: 6.6438 - val_output_coarse_loss: 4.1883 - val_output_fine_accuracy: 0.3907 - val_output_coarse_accuracy: 0.5508
# Epoch 33/50
# 313/313 [==============================] - 405s 1s/step - loss: 0.2218 - output_fine_loss: 0.1412 - output_coarse_loss: 0.0805 - output_fine_accuracy: 0.9568 - output_coarse_accuracy: 0.9745 - val_loss: 10.5714 - val_output_fine_loss: 6.4913 - val_output_coarse_loss: 4.0801 - val_output_fine_accuracy: 0.3872 - val_output_coarse_accuracy: 0.5480
# Epoch 34/50
# 313/313 [==============================] - 384s 1s/step - loss: 0.2695 - output_fine_loss: 0.1719 - output_coarse_loss: 0.0976 - output_fine_accuracy: 0.9452 - output_coarse_accuracy: 0.9682 - val_loss: 10.5467 - val_output_fine_loss: 6.5329 - val_output_coarse_loss: 4.0138 - val_output_fine_accuracy: 0.3812 - val_output_coarse_accuracy: 0.5421
# Epoch 35/50
# 313/313 [==============================] - 384s 1s/step - loss: 0.2197 - output_fine_loss: 0.1385 - output_coarse_loss: 0.0812 - output_fine_accuracy: 0.9553 - output_coarse_accuracy: 0.9736 - val_loss: 11.3462 - val_output_fine_loss: 6.9837 - val_output_coarse_loss: 4.3626 - val_output_fine_accuracy: 0.3772 - val_output_coarse_accuracy: 0.5409
# Epoch 36/50
# 313/313 [==============================] - 386s 1s/step - loss: 0.2509 - output_fine_loss: 0.1545 - output_coarse_loss: 0.0964 - output_fine_accuracy: 0.9525 - output_coarse_accuracy: 0.9698 - val_loss: 11.4299 - val_output_fine_loss: 7.0798 - val_output_coarse_loss: 4.3501 - val_output_fine_accuracy: 0.3854 - val_output_coarse_accuracy: 0.5503
# Epoch 37/50
# 313/313 [==============================] - 405s 1s/step - loss: 0.2224 - output_fine_loss: 0.1410 - output_coarse_loss: 0.0814 - output_fine_accuracy: 0.9546 - output_coarse_accuracy: 0.9739 - val_loss: 11.4403 - val_output_fine_loss: 7.0887 - val_output_coarse_loss: 4.3516 - val_output_fine_accuracy: 0.3917 - val_output_coarse_accuracy: 0.5502
# Epoch 38/50
# 313/313 [==============================] - 389s 1s/step - loss: 0.2570 - output_fine_loss: 0.1595 - output_coarse_loss: 0.0975 - output_fine_accuracy: 0.9501 - output_coarse_accuracy: 0.9694 - val_loss: 11.6230 - val_output_fine_loss: 7.2113 - val_output_coarse_loss: 4.4117 - val_output_fine_accuracy: 0.3837 - val_output_coarse_accuracy: 0.5467
# Epoch 39/50
# 313/313 [==============================] - 406s 1s/step - loss: 0.2027 - output_fine_loss: 0.1283 - output_coarse_loss: 0.0743 - output_fine_accuracy: 0.9581 - output_coarse_accuracy: 0.9753 - val_loss: 11.8179 - val_output_fine_loss: 7.3187 - val_output_coarse_loss: 4.4992 - val_output_fine_accuracy: 0.3883 - val_output_coarse_accuracy: 0.5452
# Epoch 40/50
# 313/313 [==============================] - 387s 1s/step - loss: 0.2333 - output_fine_loss: 0.1429 - output_coarse_loss: 0.0904 - output_fine_accuracy: 0.9549 - output_coarse_accuracy: 0.9719 - val_loss: 11.5689 - val_output_fine_loss: 7.2543 - val_output_coarse_loss: 4.3146 - val_output_fine_accuracy: 0.3773 - val_output_coarse_accuracy: 0.5476
# Epoch 41/50
# 313/313 [==============================] - 407s 1s/step - loss: 0.2446 - output_fine_loss: 0.1507 - output_coarse_loss: 0.0939 - output_fine_accuracy: 0.9540 - output_coarse_accuracy: 0.9709 - val_loss: 10.7187 - val_output_fine_loss: 6.6906 - val_output_coarse_loss: 4.0281 - val_output_fine_accuracy: 0.3799 - val_output_coarse_accuracy: 0.5445
# Epoch 42/50
# 313/313 [==============================] - 385s 1s/step - loss: 0.2552 - output_fine_loss: 0.1582 - output_coarse_loss: 0.0970 - output_fine_accuracy: 0.9514 - output_coarse_accuracy: 0.9693 - val_loss: 10.9633 - val_output_fine_loss: 6.8901 - val_output_coarse_loss: 4.0732 - val_output_fine_accuracy: 0.3843 - val_output_coarse_accuracy: 0.5448
# Epoch 43/50
# 313/313 [==============================] - 407s 1s/step - loss: 0.1711 - output_fine_loss: 0.1087 - output_coarse_loss: 0.0624 - output_fine_accuracy: 0.9657 - output_coarse_accuracy: 0.9803 - val_loss: 11.4709 - val_output_fine_loss: 7.2027 - val_output_coarse_loss: 4.2682 - val_output_fine_accuracy: 0.3909 - val_output_coarse_accuracy: 0.5443
# Epoch 44/50
# 313/313 [==============================] - 388s 1s/step - loss: 0.2016 - output_fine_loss: 0.1213 - output_coarse_loss: 0.0803 - output_fine_accuracy: 0.9614 - output_coarse_accuracy: 0.9747 - val_loss: 12.0554 - val_output_fine_loss: 7.5736 - val_output_coarse_loss: 4.4818 - val_output_fine_accuracy: 0.3863 - val_output_coarse_accuracy: 0.5470
# Epoch 45/50
# 313/313 [==============================] - 385s 1s/step - loss: 0.2452 - output_fine_loss: 0.1517 - output_coarse_loss: 0.0935 - output_fine_accuracy: 0.9531 - output_coarse_accuracy: 0.9703 - val_loss: 11.6415 - val_output_fine_loss: 7.3571 - val_output_coarse_loss: 4.2844 - val_output_fine_accuracy: 0.3905 - val_output_coarse_accuracy: 0.5417
# Epoch 46/50
# 313/313 [==============================] - 383s 1s/step - loss: 0.2049 - output_fine_loss: 0.1282 - output_coarse_loss: 0.0767 - output_fine_accuracy: 0.9614 - output_coarse_accuracy: 0.9762 - val_loss: 12.1026 - val_output_fine_loss: 7.5954 - val_output_coarse_loss: 4.5072 - val_output_fine_accuracy: 0.3693 - val_output_coarse_accuracy: 0.5200
# Epoch 47/50
# 313/313 [==============================] - 382s 1s/step - loss: 0.2538 - output_fine_loss: 0.1560 - output_coarse_loss: 0.0979 - output_fine_accuracy: 0.9516 - output_coarse_accuracy: 0.9699 - val_loss: 11.8635 - val_output_fine_loss: 7.5258 - val_output_coarse_loss: 4.3378 - val_output_fine_accuracy: 0.3761 - val_output_coarse_accuracy: 0.5398
# Epoch 48/50
# 313/313 [==============================] - 402s 1s/step - loss: 0.2131 - output_fine_loss: 0.1341 - output_coarse_loss: 0.0790 - output_fine_accuracy: 0.9583 - output_coarse_accuracy: 0.9747 - val_loss: 11.6104 - val_output_fine_loss: 7.3776 - val_output_coarse_loss: 4.2328 - val_output_fine_accuracy: 0.3897 - val_output_coarse_accuracy: 0.5538
# Epoch 49/50
# 313/313 [==============================] - 403s 1s/step - loss: 0.1965 - output_fine_loss: 0.1225 - output_coarse_loss: 0.0739 - output_fine_accuracy: 0.9615 - output_coarse_accuracy: 0.9772 - val_loss: 11.9078 - val_output_fine_loss: 7.5830 - val_output_coarse_loss: 4.3248 - val_output_fine_accuracy: 0.3801 - val_output_coarse_accuracy: 0.5415
# Epoch 50/50
# 313/313 [==============================] - 403s 1s/step - loss: 0.2531 - output_fine_loss: 0.1532 - output_coarse_loss: 0.0999 - output_fine_accuracy: 0.9539 - output_coarse_accuracy: 0.9686 - val_loss: 12.1228 - val_output_fine_loss: 7.7658 - val_output_coarse_loss: 4.3569 - val_output_fine_accuracy: 0.3781 - val_output_coarse_accuracy: 0.5458
# 313/313 [==============================] - 24s 76ms/step - loss: 11.8459 - output_fine_loss: 7.5695 - output_coarse_loss: 4.2764 - output_fine_accuracy: 0.3886 - output_coarse_accuracy: 0.5563
# Precisión en el conjunto de prueba (Clasificación Fina): 0.3885999917984009
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.5562999844551086
# Valor mínimo: 2.276928186416626
# Posición del valor mínimo: 6
# Valor máximo: 0.41679999232292175
# Posición del valor máximo: 9
# Valor máximo (entrenamiento): 0.965749979019165

# %% [markdown]
# ### **precisión aproximada** = 40 %

# %% [markdown]
# Observamos que se alcanza una precisión mucho más elevada que el modelo básico, pero está bastante sobreentrenado, ya que estamos realizando 50 épocas.

# %% [markdown]
# # **7.- REGULACIÓN DEL MODELO Y AJUSTE DE HIPERPARÁMETROS**

# %% [markdown]
# ### TEORIA

# %% [markdown]
# Para regular el modelo y conseguir el mínimo error con el máximo *accuracy* usaremos diferentes técnicas de regulación:
# *   **Dropout:**
#
# La capa Dropout establece aleatoriamente las unidades de entrada en 0 con una frecuencia de en cada paso durante el tiempo de entrenamiento, lo que ayuda a evitar el sobreajuste. Las entradas que no se establecen en 0 se escalan verticalmente en 1/(1 - tasa) de modo que la suma de Todas las entradas no cambian
#
# *   **Batch Normalization:**
#
# La normalización por lotes aplica una transformación que mantiene la salida media cerca de 0 y la desviación estándar de salida cercana a 1.
#
# *   **L1 y L2**
#
# En la regularización **L1**, se agrega a la función de pérdida la suma de los valores absolutos de los pesos multiplicados por un factor de regularización (
# λ).Tiene la propiedad de inducir sparsity, es decir, algunos pesos pueden volverse exactamente cero, lo que puede llevar a una selección de características automática.
#
#
# En la regularización **L2**, se agrega a la función de pérdida la suma de los cuadrados de los valores de los pesos multiplicados por un factor de regularización (λ). Penaliza los pesos grandes pero no induce sparsity, ya que todos los pesos contribuyen a la pérdida.
#
# *  **Learning back decay**
#
#
# La función callback ReduceLROnPlateau en Keras se utiliza para ajustar automáticamente la tasa de aprendizaje durante el entrenamiento del modelo. Su propósito es reducir la tasa de aprendizaje cuando ciertas condiciones se cumplen, lo que puede ayudar a mejorar la convergencia del modelo.
#
# Para nuestro modelo final vamos a utilizar el Learning back decay, las capas de dropout y las capas de bacht Normalization.

# %%
# Crear el callback ReduceLROnPlateau para ajustar la tasa de aprendizaje
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_output_fine_accuracy",
                                                 factor=0.2,  # Multiplicar la tasa de aprendizaje por 0.2 (reducir en 5 veces)
                                                 patience=3,
                                                 verbose=1,
                                                 min_lr=1e-7)
# Configurar el callback EarlyStopping para detener el entrenamiento si la pérdida en val_loss no mejora durante 5 épocas consecutivas
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_output_fine_accuracy",
                                                  patience=5)  # Si val_loss no disminuye durante 5 épocas consecutivas, se detiene el entrenamiento

# Create ModelCheckpoint callback to save best model during fine-tuning
checkpoint_path = "model_checkpoints/"
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                      save_best_only=True,
                                                      monitor="val_output_fine_accuracy")

# %% [markdown]
# ### **MODELO FINAL + mejora de añadir imagenes**

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(32, (3, 3), activation='relu', padding = 'same', input_shape=(32, 32, 3))(input_layer)
batch_norm = BatchNormalization() (conv)
conv2 = Conv2D(32, (3, 3), activation='relu', padding = 'same') (batch_norm)
batch_norm2 = BatchNormalization(axis = 3) (conv2)
pol = MaxPooling2D(pool_size=(2, 2)) (batch_norm2)
drop = Dropout(0.3) (pol)

conv3 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (drop)
batch_norm3 = BatchNormalization() (conv3)
conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (batch_norm3)
batch_norm4 = BatchNormalization(axis = 3) (conv4)
pol2 = MaxPooling2D(pool_size=(2, 2)) (batch_norm4)
drop2 = Dropout(0.3) (pol2)

conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(drop2)
batch_norm5 = BatchNormalization() (conv5)
conv6 = Conv2D(128, (3, 3), activation='relu', padding = 'same') (batch_norm5)
batch_norm6 = BatchNormalization(axis = 3) (conv6)
pol3 = MaxPooling2D(pool_size=(2, 2)) (batch_norm6)
drop3 = Dropout(0.3) (pol3)

flat = Flatten() (pol3)

dense = Dense(512, activation='relu') (flat)

batch_norm6 = BatchNormalization() (dense)
drop4 = Dropout(0.3) (batch_norm6)

dense1 = Dense(128, activation='relu') (drop4)

output_fine = Dense(100, activation='softmax', name='output_fine') (dense1)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (dense1)

model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='Adam',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

history = model.fit(train_images_validation, {'output_fine': train_labels_fine_validation, 'output_coarse': train_labels_coarse_validation},
                      epochs = 100,
                      validation_data = ( partial_train_images_validation, {'output_fine': partial_train_labels_fine_validation, 'output_coarse': partial_train_labels_coarse_validation} ),
                      callbacks = [ model_checkpoint,
                                    early_stopping,
                                    reduce_lr ] ) # Reduce el learning si el modelo no mejora en 3 épocas.

score = model.evaluate(test_images_afiladas, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])

# Graficamos la pérdida y la precisión.
history_dict = history.history
history_dict.keys()

output_fine_loss = history.history['output_fine_loss']
val_output_fine_loss = history.history['val_output_fine_loss']


epochs = range(1, len(output_fine_loss) + 1)

valor_minimo = min(val_output_fine_loss)
posicion_minimo = val_output_fine_loss.index(valor_minimo)
print("Valor mínimo:", valor_minimo)
print("Posición del valor mínimo:", posicion_minimo)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_loss, 'bo', label='Pérdida de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_loss, 'b', label='Pérdida de Validación (fine)')
plt.title('Pérdida de Entrenamiento y Validación [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine Loss')
plt.legend()

plt.show()

output_fine_accuracy = history.history['output_fine_accuracy']
val_output_fine_accuracy = history.history['val_output_fine_accuracy']

valor_maximo = max(val_output_fine_accuracy)
posicion_maximo = val_output_fine_accuracy.index(valor_maximo)
print("Valor máximo:", valor_maximo)
print("Posición del valor máximo:", posicion_maximo)

valor_maximo_entrenamiento = max(output_fine_accuracy)
posicion_maximo_entrenamiento = output_fine_accuracy.index(valor_maximo_entrenamiento)
print("Valor máximo (entrenamiento):", valor_maximo_entrenamiento)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_accuracy, 'bo', label='Precisión de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_accuracy, 'b', label='Precisión de Validación (fine)')
plt.title('Precisión de Entrenamiento y Valización [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 39s 14ms/step - loss: 5.7220 - output_fine_loss: 3.4907 - output_coarse_loss: 2.2313 - output_fine_accuracy: 0.1706 - output_coarse_accuracy: 0.3213 - val_loss: 4.7202 - val_output_fine_loss: 2.8625 - val_output_coarse_loss: 1.8578 - val_output_fine_accuracy: 0.2752 - val_output_coarse_accuracy: 0.4168 - lr: 0.0010
# Epoch 2/100
# 1563/1563 [==============================] - 22s 14ms/step - loss: 4.3052 - output_fine_loss: 2.6320 - output_coarse_loss: 1.6732 - output_fine_accuracy: 0.3212 - output_coarse_accuracy: 0.4734 - val_loss: 3.7678 - val_output_fine_loss: 2.3237 - val_output_coarse_loss: 1.4441 - val_output_fine_accuracy: 0.3768 - val_output_coarse_accuracy: 0.5348 - lr: 0.0010
# Epoch 3/100
# 1563/1563 [==============================] - 21s 14ms/step - loss: 3.7688 - output_fine_loss: 2.3149 - output_coarse_loss: 1.4538 - output_fine_accuracy: 0.3809 - output_coarse_accuracy: 0.5365 - val_loss: 3.6771 - val_output_fine_loss: 2.2696 - val_output_coarse_loss: 1.4075 - val_output_fine_accuracy: 0.3992 - val_output_coarse_accuracy: 0.5497 - lr: 0.0010
# Epoch 4/100
# 1563/1563 [==============================] - 21s 13ms/step - loss: 3.4148 - output_fine_loss: 2.1027 - output_coarse_loss: 1.3121 - output_fine_accuracy: 0.4297 - output_coarse_accuracy: 0.5770 - val_loss: 3.4266 - val_output_fine_loss: 2.1086 - val_output_coarse_loss: 1.3180 - val_output_fine_accuracy: 0.4388 - val_output_coarse_accuracy: 0.5839 - lr: 0.0010
# Epoch 5/100
# 1563/1563 [==============================] - 21s 14ms/step - loss: 3.1278 - output_fine_loss: 1.9333 - output_coarse_loss: 1.1945 - output_fine_accuracy: 0.4665 - output_coarse_accuracy: 0.6157 - val_loss: 3.2399 - val_output_fine_loss: 2.0042 - val_output_coarse_loss: 1.2358 - val_output_fine_accuracy: 0.4643 - val_output_coarse_accuracy: 0.6121 - lr: 0.0010
# Epoch 6/100
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.9235 - output_fine_loss: 1.8129 - output_coarse_loss: 1.1106 - output_fine_accuracy: 0.4949 - output_coarse_accuracy: 0.6404 - val_loss: 3.2340 - val_output_fine_loss: 1.9903 - val_output_coarse_loss: 1.2437 - val_output_fine_accuracy: 0.4719 - val_output_coarse_accuracy: 0.6100 - lr: 0.0010
# Epoch 7/100
# 1563/1563 [==============================] - 25s 16ms/step - loss: 2.7196 - output_fine_loss: 1.6941 - output_coarse_loss: 1.0255 - output_fine_accuracy: 0.5216 - output_coarse_accuracy: 0.6685 - val_loss: 3.0630 - val_output_fine_loss: 1.9011 - val_output_coarse_loss: 1.1618 - val_output_fine_accuracy: 0.4864 - val_output_coarse_accuracy: 0.6349 - lr: 0.0010
# Epoch 8/100
# 1563/1563 [==============================] - 25s 16ms/step - loss: 2.5487 - output_fine_loss: 1.5929 - output_coarse_loss: 0.9558 - output_fine_accuracy: 0.5446 - output_coarse_accuracy: 0.6897 - val_loss: 2.9827 - val_output_fine_loss: 1.8562 - val_output_coarse_loss: 1.1265 - val_output_fine_accuracy: 0.5025 - val_output_coarse_accuracy: 0.6474 - lr: 0.0010
# Epoch 9/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 2.4179 - output_fine_loss: 1.5144 - output_coarse_loss: 0.9034 - output_fine_accuracy: 0.5630 - output_coarse_accuracy: 0.7050 - val_loss: 3.0660 - val_output_fine_loss: 1.8994 - val_output_coarse_loss: 1.1666 - val_output_fine_accuracy: 0.5070 - val_output_coarse_accuracy: 0.6484 - lr: 0.0010
# Epoch 10/100
# 1563/1563 [==============================] - 21s 13ms/step - loss: 2.2656 - output_fine_loss: 1.4239 - output_coarse_loss: 0.8417 - output_fine_accuracy: 0.5825 - output_coarse_accuracy: 0.7213 - val_loss: 2.8885 - val_output_fine_loss: 1.7971 - val_output_coarse_loss: 1.0915 - val_output_fine_accuracy: 0.5222 - val_output_coarse_accuracy: 0.6675 - lr: 0.0010
# Epoch 11/100
# 1563/1563 [==============================] - 18s 12ms/step - loss: 2.1462 - output_fine_loss: 1.3562 - output_coarse_loss: 0.7901 - output_fine_accuracy: 0.6003 - output_coarse_accuracy: 0.7410 - val_loss: 2.8890 - val_output_fine_loss: 1.7932 - val_output_coarse_loss: 1.0958 - val_output_fine_accuracy: 0.5302 - val_output_coarse_accuracy: 0.6729 - lr: 0.0010
# Epoch 12/100
# 1563/1563 [==============================] - 20s 13ms/step - loss: 2.0245 - output_fine_loss: 1.2864 - output_coarse_loss: 0.7381 - output_fine_accuracy: 0.6161 - output_coarse_accuracy: 0.7545 - val_loss: 2.8635 - val_output_fine_loss: 1.7740 - val_output_coarse_loss: 1.0895 - val_output_fine_accuracy: 0.5382 - val_output_coarse_accuracy: 0.6710 - lr: 0.0010
# Epoch 13/100
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.9213 - output_fine_loss: 1.2231 - output_coarse_loss: 0.6982 - output_fine_accuracy: 0.6329 - output_coarse_accuracy: 0.7663 - val_loss: 2.8748 - val_output_fine_loss: 1.7792 - val_output_coarse_loss: 1.0956 - val_output_fine_accuracy: 0.5360 - val_output_coarse_accuracy: 0.6774 - lr: 0.0010
# Epoch 14/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.8548 - output_fine_loss: 1.1876 - output_coarse_loss: 0.6671 - output_fine_accuracy: 0.6405 - output_coarse_accuracy: 0.7775 - val_loss: 2.8707 - val_output_fine_loss: 1.7855 - val_output_coarse_loss: 1.0852 - val_output_fine_accuracy: 0.5422 - val_output_coarse_accuracy: 0.6768 - lr: 0.0010
# Epoch 15/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.7523 - output_fine_loss: 1.1238 - output_coarse_loss: 0.6286 - output_fine_accuracy: 0.6581 - output_coarse_accuracy: 0.7908 - val_loss: 2.8811 - val_output_fine_loss: 1.7832 - val_output_coarse_loss: 1.0979 - val_output_fine_accuracy: 0.5439 - val_output_coarse_accuracy: 0.6861 - lr: 0.0010
# Epoch 16/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.6784 - output_fine_loss: 1.0802 - output_coarse_loss: 0.5982 - output_fine_accuracy: 0.6677 - output_coarse_accuracy: 0.7996 - val_loss: 2.9322 - val_output_fine_loss: 1.8151 - val_output_coarse_loss: 1.1171 - val_output_fine_accuracy: 0.5488 - val_output_coarse_accuracy: 0.6832 - lr: 0.0010
# Epoch 17/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.6100 - output_fine_loss: 1.0422 - output_coarse_loss: 0.5679 - output_fine_accuracy: 0.6789 - output_coarse_accuracy: 0.8093 - val_loss: 2.9291 - val_output_fine_loss: 1.8118 - val_output_coarse_loss: 1.1173 - val_output_fine_accuracy: 0.5477 - val_output_coarse_accuracy: 0.6865 - lr: 0.0010
# Epoch 18/100
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.5449 - output_fine_loss: 1.0014 - output_coarse_loss: 0.5435 - output_fine_accuracy: 0.6868 - output_coarse_accuracy: 0.8171 - val_loss: 2.9339 - val_output_fine_loss: 1.8145 - val_output_coarse_loss: 1.1194 - val_output_fine_accuracy: 0.5496 - val_output_coarse_accuracy: 0.6856 - lr: 0.0010
# Epoch 19/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4816 - output_fine_loss: 0.9618 - output_coarse_loss: 0.5198 - output_fine_accuracy: 0.6975 - output_coarse_accuracy: 0.8254 - val_loss: 2.9152 - val_output_fine_loss: 1.8078 - val_output_coarse_loss: 1.1075 - val_output_fine_accuracy: 0.5572 - val_output_coarse_accuracy: 0.6887 - lr: 0.0010
# Epoch 20/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4287 - output_fine_loss: 0.9316 - output_coarse_loss: 0.4971 - output_fine_accuracy: 0.7074 - output_coarse_accuracy: 0.8321 - val_loss: 3.0901 - val_output_fine_loss: 1.9087 - val_output_coarse_loss: 1.1814 - val_output_fine_accuracy: 0.5457 - val_output_coarse_accuracy: 0.6861 - lr: 0.0010
# Epoch 21/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.3828 - output_fine_loss: 0.9034 - output_coarse_loss: 0.4794 - output_fine_accuracy: 0.7154 - output_coarse_accuracy: 0.8376 - val_loss: 2.9908 - val_output_fine_loss: 1.8460 - val_output_coarse_loss: 1.1448 - val_output_fine_accuracy: 0.5541 - val_output_coarse_accuracy: 0.6846 - lr: 0.0010
# Epoch 22/100
# 1560/1563 [============================>.] - ETA: 0s - loss: 1.3509 - output_fine_loss: 0.8841 - output_coarse_loss: 0.4668 - output_fine_accuracy: 0.7206 - output_coarse_accuracy: 0.8410
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3509 - output_fine_loss: 0.8841 - output_coarse_loss: 0.4668 - output_fine_accuracy: 0.7206 - output_coarse_accuracy: 0.8411 - val_loss: 3.0491 - val_output_fine_loss: 1.8920 - val_output_coarse_loss: 1.1571 - val_output_fine_accuracy: 0.5465 - val_output_coarse_accuracy: 0.6887 - lr: 0.0010
# Epoch 23/100
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.0372 - output_fine_loss: 0.6934 - output_coarse_loss: 0.3438 - output_fine_accuracy: 0.7721 - output_coarse_accuracy: 0.8838 - val_loss: 2.9472 - val_output_fine_loss: 1.8205 - val_output_coarse_loss: 1.1266 - val_output_fine_accuracy: 0.5723 - val_output_coarse_accuracy: 0.7099 - lr: 2.0000e-04
# Epoch 24/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9155 - output_fine_loss: 0.6223 - output_coarse_loss: 0.2933 - output_fine_accuracy: 0.7944 - output_coarse_accuracy: 0.9002 - val_loss: 2.9748 - val_output_fine_loss: 1.8354 - val_output_coarse_loss: 1.1394 - val_output_fine_accuracy: 0.5777 - val_output_coarse_accuracy: 0.7092 - lr: 2.0000e-04
# Epoch 25/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8728 - output_fine_loss: 0.5940 - output_coarse_loss: 0.2788 - output_fine_accuracy: 0.8027 - output_coarse_accuracy: 0.9042 - val_loss: 3.0074 - val_output_fine_loss: 1.8516 - val_output_coarse_loss: 1.1558 - val_output_fine_accuracy: 0.5790 - val_output_coarse_accuracy: 0.7081 - lr: 2.0000e-04
# Epoch 26/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.8340 - output_fine_loss: 0.5716 - output_coarse_loss: 0.2624 - output_fine_accuracy: 0.8097 - output_coarse_accuracy: 0.9099 - val_loss: 3.0451 - val_output_fine_loss: 1.8716 - val_output_coarse_loss: 1.1735 - val_output_fine_accuracy: 0.5809 - val_output_coarse_accuracy: 0.7091 - lr: 2.0000e-04
# Epoch 27/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7865 - output_fine_loss: 0.5411 - output_coarse_loss: 0.2454 - output_fine_accuracy: 0.8199 - output_coarse_accuracy: 0.9157 - val_loss: 3.0688 - val_output_fine_loss: 1.8824 - val_output_coarse_loss: 1.1865 - val_output_fine_accuracy: 0.5810 - val_output_coarse_accuracy: 0.7086 - lr: 2.0000e-04
# Epoch 28/100
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.7657 - output_fine_loss: 0.5249 - output_coarse_loss: 0.2407 - output_fine_accuracy: 0.8251 - output_coarse_accuracy: 0.9171 - val_loss: 3.1047 - val_output_fine_loss: 1.9001 - val_output_coarse_loss: 1.2046 - val_output_fine_accuracy: 0.5818 - val_output_coarse_accuracy: 0.7127 - lr: 2.0000e-04
# Epoch 29/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7447 - output_fine_loss: 0.5132 - output_coarse_loss: 0.2315 - output_fine_accuracy: 0.8270 - output_coarse_accuracy: 0.9202 - val_loss: 3.1385 - val_output_fine_loss: 1.9180 - val_output_coarse_loss: 1.2205 - val_output_fine_accuracy: 0.5796 - val_output_coarse_accuracy: 0.7115 - lr: 2.0000e-04
# Epoch 30/100
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.7111 - output_fine_loss: 0.4914 - output_coarse_loss: 0.2197 - output_fine_accuracy: 0.8354 - output_coarse_accuracy: 0.9239 - val_loss: 3.1676 - val_output_fine_loss: 1.9347 - val_output_coarse_loss: 1.2329 - val_output_fine_accuracy: 0.5812 - val_output_coarse_accuracy: 0.7106 - lr: 2.0000e-04
# Epoch 31/100
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.6907 - output_fine_loss: 0.4791 - output_coarse_loss: 0.2116 - output_fine_accuracy: 0.8388 - output_coarse_accuracy: 0.9267
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6910 - output_fine_loss: 0.4792 - output_coarse_loss: 0.2118 - output_fine_accuracy: 0.8387 - output_coarse_accuracy: 0.9267 - val_loss: 3.1989 - val_output_fine_loss: 1.9485 - val_output_coarse_loss: 1.2504 - val_output_fine_accuracy: 0.5795 - val_output_coarse_accuracy: 0.7109 - lr: 2.0000e-04
# Epoch 32/100
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6515 - output_fine_loss: 0.4560 - output_coarse_loss: 0.1955 - output_fine_accuracy: 0.8443 - output_coarse_accuracy: 0.9332 - val_loss: 3.1800 - val_output_fine_loss: 1.9400 - val_output_coarse_loss: 1.2400 - val_output_fine_accuracy: 0.5802 - val_output_coarse_accuracy: 0.7106 - lr: 4.0000e-05
# Epoch 33/100
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.6333 - output_fine_loss: 0.4419 - output_coarse_loss: 0.1914 - output_fine_accuracy: 0.8496 - output_coarse_accuracy: 0.9346 - val_loss: 3.1870 - val_output_fine_loss: 1.9436 - val_output_coarse_loss: 1.2434 - val_output_fine_accuracy: 0.5815 - val_output_coarse_accuracy: 0.7101 - lr: 4.0000e-05
# 313/313 [==============================] - 1s 5ms/step - loss: 3.1870 - output_fine_loss: 1.9436 - output_coarse_loss: 1.2434 - output_fine_accuracy: 0.5815 - output_coarse_accuracy: 0.7101
# Precisión en el conjunto de prueba (Clasificación Fina): 0.5814999938011169
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.710099995136261
# Valor mínimo: 1.7739769220352173
# Posición del valor mínimo: 11
# Valor máximo: 0.5817999839782715
# Posición del valor máximo: 27
# Valor máximo (entrenamiento): 0.8496000170707703

# %% [markdown]
# **Precisión aproximada** = *57.16*%

# %% [markdown]
# Añadiendo cambios en las imagenes:
# Por último, como modelo final vamos a añadir cambios en las imagenes y vamos a suprimir la segunda salida, ya que aunque se esté perdiendo parte de la información, si es modelo acierta la clase fina, va a acertar la clase gruesa.
#
# https://www.kaggle.com/code/harshrachalwar/transformers-for-image-recognition-at-scale en este proyecto se puede ver como utilizar el data augmentation . Esto introduce variabilidad al aplicar transformaciones aleatorias, como rotaciones, escalados, recortes y cambios en la iluminación, a las imágenes originales. Esto ayuda a que el modelo se vuelva más robusto al considerar diferentes perspectivas y variaciones de los objetos en las imágenes. También se utiliza como técnica de regularización para evitar sobrentrenamiento, ya que reduce el posible sesgo.

# %%
# Crear el callback ReduceLROnPlateau para ajustar la tasa de aprendizaje
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_output_fine_accuracy",
                                                 factor=0.2,  # Multiplicar la tasa de aprendizaje por 0.2 (reducir en 5 veces)
                                                 patience=3,
                                                 verbose=1,
                                                 min_lr=1e-7)
# Configurar el callback EarlyStopping para detener el entrenamiento si la pérdida en val_loss no mejora durante 5 épocas consecutivas
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_output_fine_accuracy",
                                                  patience=5)  # Si val_loss no disminuye durante 5 épocas consecutivas, se detiene el entrenamiento

# Create ModelCheckpoint callback to save best model during fine-tuning
checkpoint_path = "model_checkpoints/"
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                      save_best_only=True,
                                                      monitor="val_output_fine_accuracy")

# %%
# Define el generador de imágenes con las transformaciones deseadas
datagen = ImageDataGenerator(
    rotation_range=20,  # Rango de rotación en grados
    width_shift_range=0.2,  # Rango de cambio de ancho
    height_shift_range=0.2,  # Rango de cambio de alto
    shear_range=0.2,  # Rango de deformación
    zoom_range=0.2,  # Rango de zoom
    horizontal_flip=True,  # Volteo horizontal aleatorio
    fill_mode='nearest'  # Estrategia de relleno en caso de transformaciones
)

# Ajusta el generador a tus datos de entrenamiento
datagen.fit(train_images_validation)

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(32, (3, 3), activation='relu', padding = 'same', input_shape=(32, 32, 3))(input_layer)
batch_norm = BatchNormalization() (conv)
conv2 = Conv2D(32, (3, 3), activation='relu', padding = 'same') (batch_norm)
batch_norm2 = BatchNormalization(axis = 3) (conv2)
pol = MaxPooling2D(pool_size=(2, 2)) (batch_norm2)
drop = Dropout(0.3) (pol)

conv3 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (drop)
batch_norm3 = BatchNormalization() (conv3)
conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (batch_norm3)
batch_norm4 = BatchNormalization(axis = 3) (conv4)
pol2 = MaxPooling2D(pool_size=(2, 2)) (batch_norm4)
drop2 = Dropout(0.3) (pol2)

conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(drop2)
batch_norm5 = BatchNormalization() (conv5)
conv6 = Conv2D(128, (3, 3), activation='relu', padding = 'same') (batch_norm5)
batch_norm6 = BatchNormalization(axis = 3) (conv6)
pol3 = MaxPooling2D(pool_size=(2, 2)) (batch_norm6)
drop3 = Dropout(0.3) (pol3)

flat = Flatten() (pol3)

dense = Dense(512, activation='relu') (flat)

batch_norm6 = BatchNormalization() (dense)
drop4 = Dropout(0.3) (batch_norm6)

dense1 = Dense(128, activation='relu') (drop4)

output_fine = Dense(100, activation='softmax', name='output_fine') (dense1)

model = Model(inputs=input_layer, outputs=output_fine)

model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

history = model.fit(datagen.flow(train_images_validation, train_labels_fine_validation, batch_size=128),
                    epochs=45,
                    validation_data=(partial_train_images_validation, partial_train_labels_fine_validation))
# Out:
# Epoch 1/45
# 313/313 [==============================] - 36s 93ms/step - loss: 4.0156 - accuracy: 0.0919 - val_loss: 5.3880 - val_accuracy: 0.0231
# Epoch 2/45
# 313/313 [==============================] - 29s 91ms/step - loss: 3.5164 - accuracy: 0.1602 - val_loss: 3.3809 - val_accuracy: 0.1917
# Epoch 3/45
# 313/313 [==============================] - 28s 91ms/step - loss: 3.2399 - accuracy: 0.2091 - val_loss: 3.3154 - val_accuracy: 0.2129
# Epoch 4/45
# 313/313 [==============================] - 28s 90ms/step - loss: 3.0571 - accuracy: 0.2394 - val_loss: 2.9052 - val_accuracy: 0.2818
# Epoch 5/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.8975 - accuracy: 0.2661 - val_loss: 2.9779 - val_accuracy: 0.2752
# Epoch 6/45
# 313/313 [==============================] - 29s 91ms/step - loss: 2.7638 - accuracy: 0.2992 - val_loss: 2.8299 - val_accuracy: 0.2952
# Epoch 7/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.6669 - accuracy: 0.3169 - val_loss: 2.7873 - val_accuracy: 0.3077
# Epoch 8/45
# 313/313 [==============================] - 29s 92ms/step - loss: 2.5703 - accuracy: 0.3318 - val_loss: 2.5898 - val_accuracy: 0.3597
# Epoch 9/45
# 313/313 [==============================] - 28s 90ms/step - loss: 2.4736 - accuracy: 0.3549 - val_loss: 2.4920 - val_accuracy: 0.3716
# Epoch 10/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.3942 - accuracy: 0.3689 - val_loss: 2.2834 - val_accuracy: 0.4112
# Epoch 11/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.3400 - accuracy: 0.3817 - val_loss: 2.2845 - val_accuracy: 0.4098
# Epoch 12/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.2869 - accuracy: 0.3930 - val_loss: 2.3408 - val_accuracy: 0.4023
# Epoch 13/45
# 313/313 [==============================] - 29s 91ms/step - loss: 2.2313 - accuracy: 0.4015 - val_loss: 2.2316 - val_accuracy: 0.4255
# Epoch 14/45
# 313/313 [==============================] - 29s 91ms/step - loss: 2.1856 - accuracy: 0.4135 - val_loss: 2.2000 - val_accuracy: 0.4331
# Epoch 15/45
# 313/313 [==============================] - 30s 95ms/step - loss: 2.1372 - accuracy: 0.4265 - val_loss: 2.0897 - val_accuracy: 0.4553
# Epoch 16/45
# 313/313 [==============================] - 28s 91ms/step - loss: 2.0929 - accuracy: 0.4353 - val_loss: 2.2506 - val_accuracy: 0.4237
# Epoch 17/45
# 313/313 [==============================] - 28s 90ms/step - loss: 2.0591 - accuracy: 0.4442 - val_loss: 2.1049 - val_accuracy: 0.4594
# Epoch 18/45
# 313/313 [==============================] - 29s 94ms/step - loss: 2.0323 - accuracy: 0.4481 - val_loss: 2.1050 - val_accuracy: 0.4576
# Epoch 19/45
# 313/313 [==============================] - 28s 90ms/step - loss: 1.9944 - accuracy: 0.4574 - val_loss: 1.9902 - val_accuracy: 0.4732
# Epoch 20/45
# 313/313 [==============================] - 28s 90ms/step - loss: 1.9816 - accuracy: 0.4610 - val_loss: 2.2524 - val_accuracy: 0.4405
# Epoch 21/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.9468 - accuracy: 0.4697 - val_loss: 1.9914 - val_accuracy: 0.4833
# Epoch 22/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.9214 - accuracy: 0.4744 - val_loss: 1.8987 - val_accuracy: 0.4987
# Epoch 23/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.8979 - accuracy: 0.4800 - val_loss: 1.9511 - val_accuracy: 0.4928
# Epoch 24/45
# 313/313 [==============================] - 28s 90ms/step - loss: 1.8736 - accuracy: 0.4863 - val_loss: 1.9646 - val_accuracy: 0.4955
# Epoch 25/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.8616 - accuracy: 0.4898 - val_loss: 2.2329 - val_accuracy: 0.4528
# Epoch 26/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.8354 - accuracy: 0.4966 - val_loss: 1.9851 - val_accuracy: 0.4864
# Epoch 27/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.8130 - accuracy: 0.5019 - val_loss: 1.9790 - val_accuracy: 0.4943
# Epoch 28/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.8008 - accuracy: 0.5026 - val_loss: 2.0708 - val_accuracy: 0.4826
# Epoch 29/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.7944 - accuracy: 0.5051 - val_loss: 1.8242 - val_accuracy: 0.5134
# Epoch 30/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.7679 - accuracy: 0.5101 - val_loss: 2.1701 - val_accuracy: 0.4672
# Epoch 31/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.7461 - accuracy: 0.5153 - val_loss: 1.9242 - val_accuracy: 0.5049
# Epoch 32/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.7335 - accuracy: 0.5195 - val_loss: 1.8709 - val_accuracy: 0.5124
# Epoch 33/45
# 313/313 [==============================] - 29s 94ms/step - loss: 1.7159 - accuracy: 0.5233 - val_loss: 1.8123 - val_accuracy: 0.5286
# Epoch 34/45
# 313/313 [==============================] - 29s 93ms/step - loss: 1.7115 - accuracy: 0.5224 - val_loss: 2.0103 - val_accuracy: 0.4917
# Epoch 35/45
# 313/313 [==============================] - 29s 93ms/step - loss: 1.7000 - accuracy: 0.5282 - val_loss: 1.8124 - val_accuracy: 0.5278
# Epoch 36/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.6792 - accuracy: 0.5296 - val_loss: 1.8723 - val_accuracy: 0.5216
# Epoch 37/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.6708 - accuracy: 0.5343 - val_loss: 1.8839 - val_accuracy: 0.5174
# Epoch 38/45
# 313/313 [==============================] - 29s 93ms/step - loss: 1.6567 - accuracy: 0.5372 - val_loss: 1.9295 - val_accuracy: 0.5020
# Epoch 39/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.6474 - accuracy: 0.5402 - val_loss: 1.8409 - val_accuracy: 0.5197
# Epoch 40/45
# 313/313 [==============================] - 29s 94ms/step - loss: 1.6310 - accuracy: 0.5408 - val_loss: 1.8003 - val_accuracy: 0.5279
# Epoch 41/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.6340 - accuracy: 0.5421 - val_loss: 1.7530 - val_accuracy: 0.5466
# Epoch 42/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.6065 - accuracy: 0.5499 - val_loss: 1.8352 - val_accuracy: 0.5308
# Epoch 43/45
# 313/313 [==============================] - 29s 91ms/step - loss: 1.6056 - accuracy: 0.5491 - val_loss: 1.8073 - val_accuracy: 0.5333
# Epoch 44/45
# 313/313 [==============================] - 29s 92ms/step - loss: 1.5907 - accuracy: 0.5513 - val_loss: 1.8177 - val_accuracy: 0.5297
# Epoch 45/45
# 313/313 [==============================] - 28s 91ms/step - loss: 1.5855 - accuracy: 0.5529 - val_loss: 1.7311 - val_accuracy: 0.5390

# %%
# Graficamos la pérdida y la precisión.
history_dict = history.history
history_dict.keys()

# Obtén las claves correctas del historial
output_fine_loss = history_dict['loss']
val_output_fine_loss = history_dict['val_loss']

epochs = range(1, len(output_fine_loss) + 1)

valor_minimo = min(val_output_fine_loss)
posicion_minimo = val_output_fine_loss.index(valor_minimo)
print("Valor mínimo:", valor_minimo)
print("Posición del valor mínimo:", posicion_minimo)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_loss, 'bo', label='Pérdida de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_loss, 'b', label='Pérdida de Validación (fine)')
plt.title('Pérdida de Entrenamiento y Validación [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine Loss')
plt.legend()

plt.show()

output_fine_accuracy = history_dict['accuracy']
val_output_fine_accuracy = history_dict['val_accuracy']

valor_maximo = max(val_output_fine_accuracy)
posicion_maximo = val_output_fine_accuracy.index(valor_maximo)
print("Valor máximo:", valor_maximo)
print("Posición del valor máximo:", posicion_maximo)

valor_maximo_entrenamiento = max(output_fine_accuracy)
posicion_maximo_entrenamiento = output_fine_accuracy.index(valor_maximo_entrenamiento)
print("Valor máximo (entrenamiento):", valor_maximo_entrenamiento)

# "bo" es para "punto azul"
plt.plot(epochs, output_fine_accuracy, 'bo', label='Precisión de Entrenamiento (fine)')
# "b" es para "linea continua azul"
plt.plot(epochs, val_output_fine_accuracy, 'b', label='Precisión de Validación (fine)')
plt.title('Precisión de Entrenamiento y Valización [ fine ]')
plt.xlabel('Epochs')
plt.ylabel('Fine accuracy')
plt.legend()

plt.show()
# Out:
# Valor mínimo: 1.7311017513275146
# Posición del valor mínimo: 44
# Valor máximo: 0.5465999841690063
# Posición del valor máximo: 40
# Valor máximo (entrenamiento): 0.5529249906539917

# %% [markdown]
# **PRECISIÓN APROXIMADA: 55%**
# Observamos que el datagen es útil, pero en nuestro caso con las medidas de batch_normalization y dropout ya conseguimos evitar el sobrentrenamiento.
#
#
# Una vez conocemos el número de épcas, calculado anteriormente, así quedaria el modelo final:

# %%
input_layer = Input(shape=(32, 32, 3))

conv = Conv2D(32, (3, 3), activation='relu', padding = 'same', input_shape=(32, 32, 3))(input_layer)
batch_norm = BatchNormalization() (conv)
conv2 = Conv2D(32, (3, 3), activation='relu', padding = 'same') (batch_norm)
batch_norm2 = BatchNormalization(axis = 3) (conv2)
pol = MaxPooling2D(pool_size=(2, 2)) (batch_norm2)
drop = Dropout(0.3) (pol)

conv3 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (drop)
batch_norm3 = BatchNormalization() (conv3)
conv4 = Conv2D(64, (3, 3), activation='relu', padding = 'same') (batch_norm3)
batch_norm4 = BatchNormalization(axis = 3) (conv4)
pol2 = MaxPooling2D(pool_size=(2, 2)) (batch_norm4)
drop2 = Dropout(0.3) (pol2)

conv5 = Conv2D(128, (3, 3), activation='relu', padding = 'same')(drop2)
batch_norm5 = BatchNormalization() (conv5)
conv6 = Conv2D(128, (3, 3), activation='relu', padding = 'same') (batch_norm5)
batch_norm6 = BatchNormalization(axis = 3) (conv6)
pol3 = MaxPooling2D(pool_size=(2, 2)) (batch_norm6)
drop3 = Dropout(0.3) (pol3)

flat = Flatten() (pol3)

dense = Dense(512, activation='relu') (flat)

batch_norm6 = BatchNormalization() (dense)
drop4 = Dropout(0.3) (batch_norm6)

dense1 = Dense(128, activation='relu') (drop4)

output_fine = Dense(100, activation='softmax', name='output_fine') (dense1)
output_coarse = Dense(20, activation='softmax', name='output_coarse') (dense1)

model = Model(inputs=input_layer, outputs=[output_fine, output_coarse])

model.compile(loss={'output_fine': 'categorical_crossentropy', 'output_coarse': 'categorical_crossentropy'},
              optimizer='Adam',
              metrics={'output_fine': 'accuracy', 'output_coarse': 'accuracy'})

model.fit(train_images_afiladas, {'output_fine': train_labels_fine, 'output_coarse': train_labels_coarse},
                      epochs = 27)

score = model.evaluate(test_images_afiladas, {'output_fine': test_labels_fine, 'output_coarse': test_labels_coarse})
print("Precisión en el conjunto de prueba (Clasificación Fina):", score[3])
print("Precisión en el conjunto de prueba (Clasificación Gruesa):", score[4])
# Out:
# Epoch 1/27
# 1563/1563 [==============================] - 37s 12ms/step - loss: 5.7133 - output_fine_loss: 3.4902 - output_coarse_loss: 2.2231 - output_fine_accuracy: 0.1699 - output_coarse_accuracy: 0.3208
# Epoch 2/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 4.3582 - output_fine_loss: 2.6686 - output_coarse_loss: 1.6895 - output_fine_accuracy: 0.3083 - output_coarse_accuracy: 0.4643
# Epoch 3/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 3.8455 - output_fine_loss: 2.3597 - output_coarse_loss: 1.4858 - output_fine_accuracy: 0.3728 - output_coarse_accuracy: 0.5270
# Epoch 4/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 3.4688 - output_fine_loss: 2.1358 - output_coarse_loss: 1.3329 - output_fine_accuracy: 0.4225 - output_coarse_accuracy: 0.5732
# Epoch 5/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 3.1847 - output_fine_loss: 1.9656 - output_coarse_loss: 1.2191 - output_fine_accuracy: 0.4566 - output_coarse_accuracy: 0.6070
# Epoch 6/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.9561 - output_fine_loss: 1.8321 - output_coarse_loss: 1.1240 - output_fine_accuracy: 0.4896 - output_coarse_accuracy: 0.6387
# Epoch 7/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 2.7494 - output_fine_loss: 1.7071 - output_coarse_loss: 1.0423 - output_fine_accuracy: 0.5198 - output_coarse_accuracy: 0.6614
# Epoch 8/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 2.5837 - output_fine_loss: 1.6110 - output_coarse_loss: 0.9727 - output_fine_accuracy: 0.5394 - output_coarse_accuracy: 0.6840
# Epoch 9/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.4298 - output_fine_loss: 1.5229 - output_coarse_loss: 0.9069 - output_fine_accuracy: 0.5629 - output_coarse_accuracy: 0.7041
# Epoch 10/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 2.3090 - output_fine_loss: 1.4536 - output_coarse_loss: 0.8553 - output_fine_accuracy: 0.5774 - output_coarse_accuracy: 0.7204
# Epoch 11/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 2.1765 - output_fine_loss: 1.3744 - output_coarse_loss: 0.8021 - output_fine_accuracy: 0.5964 - output_coarse_accuracy: 0.7353
# Epoch 12/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.0804 - output_fine_loss: 1.3177 - output_coarse_loss: 0.7627 - output_fine_accuracy: 0.6053 - output_coarse_accuracy: 0.7471
# Epoch 13/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.9661 - output_fine_loss: 1.2500 - output_coarse_loss: 0.7161 - output_fine_accuracy: 0.6249 - output_coarse_accuracy: 0.7637
# Epoch 14/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.8666 - output_fine_loss: 1.1932 - output_coarse_loss: 0.6733 - output_fine_accuracy: 0.6404 - output_coarse_accuracy: 0.7766
# Epoch 15/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.7946 - output_fine_loss: 1.1481 - output_coarse_loss: 0.6465 - output_fine_accuracy: 0.6497 - output_coarse_accuracy: 0.7855
# Epoch 16/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.7015 - output_fine_loss: 1.0969 - output_coarse_loss: 0.6046 - output_fine_accuracy: 0.6636 - output_coarse_accuracy: 0.7982
# Epoch 17/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.6332 - output_fine_loss: 1.0565 - output_coarse_loss: 0.5767 - output_fine_accuracy: 0.6760 - output_coarse_accuracy: 0.8059
# Epoch 18/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.5829 - output_fine_loss: 1.0242 - output_coarse_loss: 0.5587 - output_fine_accuracy: 0.6814 - output_coarse_accuracy: 0.8108
# Epoch 19/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.5181 - output_fine_loss: 0.9867 - output_coarse_loss: 0.5314 - output_fine_accuracy: 0.6927 - output_coarse_accuracy: 0.8212
# Epoch 20/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.4749 - output_fine_loss: 0.9625 - output_coarse_loss: 0.5124 - output_fine_accuracy: 0.6977 - output_coarse_accuracy: 0.8271
# Epoch 21/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.4105 - output_fine_loss: 0.9223 - output_coarse_loss: 0.4882 - output_fine_accuracy: 0.7096 - output_coarse_accuracy: 0.8354
# Epoch 22/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.3678 - output_fine_loss: 0.8946 - output_coarse_loss: 0.4732 - output_fine_accuracy: 0.7181 - output_coarse_accuracy: 0.8388
# Epoch 23/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.3314 - output_fine_loss: 0.8716 - output_coarse_loss: 0.4598 - output_fine_accuracy: 0.7229 - output_coarse_accuracy: 0.8438
# Epoch 24/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.2874 - output_fine_loss: 0.8457 - output_coarse_loss: 0.4417 - output_fine_accuracy: 0.7315 - output_coarse_accuracy: 0.8514
# Epoch 25/27
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.2504 - output_fine_loss: 0.8228 - output_coarse_loss: 0.4277 - output_fine_accuracy: 0.7364 - output_coarse_accuracy: 0.8547
# Epoch 26/27
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.2163 - output_fine_loss: 0.8062 - output_coarse_loss: 0.4101 - output_fine_accuracy: 0.7437 - output_coarse_accuracy: 0.8607
# Epoch 27/27
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.1875 - output_fine_loss: 0.7868 - output_coarse_loss: 0.4008 - output_fine_accuracy: 0.7466 - output_coarse_accuracy: 0.8638
# 313/313 [==============================] - 3s 7ms/step - loss: 3.1294 - output_fine_loss: 1.9262 - output_coarse_loss: 1.2031 - output_fine_accuracy: 0.5569 - output_coarse_accuracy: 0.6891
# Precisión en el conjunto de prueba (Clasificación Fina): 0.5569000244140625
# Precisión en el conjunto de prueba (Clasificación Gruesa): 0.6891000270843506

# %% [markdown]
# Se observa que el modelo final, con el número de épocas calculadas con la validación.
# **Resultado final: 55%**
# Relevante mencionar que obviamente la clasificación de las clases gruesas es mucho mayor, ya que son muchas menos categorías. Esto quiere decir que para algunas images, el modelo es capaz de, por lo menos, acertar la categoría gruesa aunque se equivoque en la fina. Si quitamos la clasificación gruesa estariamos perdiendo un poco de información.

# %% [markdown]
# ### **ANÁLISIS - CONCLUSIONES**

# %% [markdown]
# **Sumary:**
#
# Hacemos un analisis del número de parametros que hay en el modelo. Habría que tener en cuenta que añadir más capas ocultas haría que el número de parametros aumente.

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)           896       ['input_3[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 32)           128       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)           9248      ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 32)           128       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 32)           0         ['batch_normalization_15[0][0]
#  g2D)                                                               ']
#
#  dropout_8 (Dropout)         (None, 16, 16, 32)           0         ['max_pooling2d_6[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 64)           18496     ['dropout_8[0][0]']
#
#  batch_normalization_16 (Ba  (None, 16, 16, 64)           256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 64)           36928     ['batch_normalization_16[0][0]
#                                                                     ']
#
#  batch_normalization_17 (Ba  (None, 16, 16, 64)           256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 64)             0         ['batch_normalization_17[0][0]
#  g2D)                                                               ']
#
#  dropout_9 (Dropout)         (None, 8, 8, 64)             0         ['max_pooling2d_7[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)            73856     ['dropout_9[0][0]']
#
#  batch_normalization_18 (Ba  (None, 8, 8, 128)            512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 128)            147584    ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 8, 8, 128)            512       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 128)            0         ['batch_normalization_19[0][0]
#  g2D)                                                               ']
#
#  flatten_2 (Flatten)         (None, 2048)                 0         ['max_pooling2d_8[0][0]']
#
#  dense_4 (Dense)             (None, 512)                  1049088   ['flatten_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 512)                  2048      ['dense_4[0][0]']
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 512)                  0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  dense_5 (Dense)             (None, 128)                  65664     ['dropout_11[0][0]']
#
#  output_fine (Dense)         (None, 100)                  12900     ['dense_5[0][0]']
#
#  output_coarse (Dense)       (None, 20)                   2580      ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 1421080 (5.42 MB)
# Trainable params: 1419160 (5.41 MB)
# Non-trainable params: 1920 (7.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Summary:**
#
# Calculamos el número de parámetros:
#
#
# Input_layer: no tiene parámetros entrenables, es solo la capa de entrada.
#
#
# Conv2d_12: (3 x 3) tamaño filtro x 3 entradas al filtro x 32 filtros + 32 sesgo = 896
#
#
# Capa Batch_normalization_14: 128
#
#
# Conv2d_13: ((3 x 3) tamaño filtro x 32 entradas al filtro + 1 sesgo) x 32 filtros = 9248
#
#
# Capa Batch_normalization_15: 128
#
#
# Max_pooling2d_6: 0, no tiene parámetros entrenables, se encarga de filtrar.
#
#
# Dropout_8: 0, tampoco tiene parámetros entrenables.
#
#
# Conv2d_14: ((3 x 3) tamaño filtro x 32 entradas al filtro + 1 sesgo) x 64 filtros = 18496
#
#
# Batch_normalization_16: 256
#
#
# Conv2d_15:((3 x 3) tamaño filtro x 64 entradas + 1 sesgo) x 64 filtros = 36928
#
#
# max_pooling2d_7: 0, no tiene parámetros entrenables, se encarga de filtrar.
#
#
# dropout_9: 0, no tiene parámetros entrenables.
#
#
# conv2d_16: ((3 x 3) tamaño del filtro x 64 entradas + 1 sesgo) x 128 filtros = 73856
#
#
# batch_normalization_18: 256
#
#
# conv2d_17: ((3 x 3) tamaño filtro x 128 entradas + 1 sesgo) x 128 filtros = 147584
#
#
# batch_normalization_19: 512
#
#
# max_pooling2d_8: 0, no tiene parámetros entrenables, se encarga de filtrar.
#
#
# flatten_2: 0, no tiene parámetros entrenables se encarga de aplanar
#
#
# dense_4: 1049088
#
#
# batch_normalization_20: 2048
#
#
# dropout_11:0, no tiene parámetros entrenables.
#
#
# dense_5: 65664
#
#
# Parámetros totales = 1421080

# %% [markdown]
# **Matriz de Confusión:**

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Obtén las predicciones del modelo en el conjunto de prueba
predictions_fine = model.predict(test_images_afiladas)[0]

# Convierte las predicciones a clases (índices de las clases con mayor probabilidad)
predicted_classes_fine = np.argmax(predictions_fine, axis=1)

# Convierte las etiquetas reales a clases
true_classes_fine = np.argmax(test_labels_fine, axis=1)

# Obtén el nombre de las clases finas
#labels_fine = [obtener_clase(i) for i in range(100)]
labels_fine = [
    "beaver", "dolphin", "otter", "seal", "whale",
    "aquarium fish", "flatfish", "ray", "shark", "trout",
    "orchids", "poppies", "roses", "sunflowers", "tulips",
    "bottles", "bowls", "cans", "cups", "plates",
    "apples", "mushrooms", "oranges", "pears", "sweet peppers",
    "clock", "computer keyboard", "lamp", "telephone", "television",
    "bed", "chair", "couch", "table", "wardrobe",
    "bee", "beetle", "butterfly", "caterpillar", "cockroach",
    "bear", "leopard", "lion", "tiger", "wolf",
    "bridge", "castle", "house", "road", "skyscraper",
    "cloud", "forest", "mountain", "plain", "sea",
    "camel", "cattle", "chimpanzee", "elephant", "kangaroo",
    "fox", "porcupine", "possum", "raccoon", "skunk",
    "crab", "lobster", "snail", "spider", "worm",
    "baby", "boy", "girl", "man", "woman",
    "crocodile", "dinosaur", "lizard", "snake", "turtle",
    "hamster", "mouse", "rabbit", "shrew", "squirrel",
    "maple", "oak", "palm", "pine", "willow",
    "bicycle", "bus", "motorcycle", "pickup truck", "train",
    "lawn-mower", "rocket", "streetcar", "tank", "tractor"
    ]

labels_fine.sort()

# Crea la matriz de confusión
cm_fine = confusion_matrix(true_classes_fine, predicted_classes_fine)

# Visualiza la matriz de confusión usando seaborn con un colormap
plt.figure(figsize=(18, 18))
sns.heatmap(cm_fine, annot=False, cbar=True, square=True, xticklabels=labels_fine, yticklabels=labels_fine)
# sns.heatmap(cm_fine, annot=False, cbar=True, square=True)

# labels, title and ticks
plt.title("Matriz de Confusión (Clasificación Fina)")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")

plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# En esta matriz de confusión se muestran las predicciones. En la diagonal principal se observan los verdaderos positivos y obviamente el porcetaje de acierto es bastante alto.Al existir tantas clases es dificil comprender los resultados de cada clase, aunque por ejemplo, se ve claramente como el modelo distinge mejor la clase "apple", que la clase "woman".

# %% [markdown]
# ## CONLCUSIÓN

# %% [markdown]
# En este proyecto se ha abordado la mejora de la precisión mediante la exploración de técnicas de ingeniería de características, ajuste de la arquitectura del modelo y la aplicación de técnicas de regularización.
#
# La ingeniería de características ha desempeñado un papel fundamental en la mejora de la precisión de nuestro modelo de aprendizaje automático. En particular, la aplicación de la afilación de imágenes ha demostrado ser una estrategia efectiva para resaltar características relevantes en las imágenes de nuestro conjunto de datos. Esta técnica parece haber contribuido significativamente a la capacidad del modelo para discernir patrones importantes durante el entrenamiento. Por otro lado, la aplicación del filtro de Laplace no generó mejoras sustanciales y fue descartado (aunque para otro tipo de datos podría funcionar), destacando la importancia de evaluar críticamente cada transformación aplicada. También se ha analizado una técnica para el aumento del tamaño de las imagenes. Esto habría sido muy útil si dispusiéramos de los recursos para obtener imágenes de, por ejemplo 128x128 píxeles.
#
# La construcción de un modelo de referencia sólido fue esencial para establecer un punto de comparación durante el desarrollo del proyecto. Este modelo inicial, con una estructura simple que incluye capas convolucionales y densas, proporcionó una referencia clara para evaluar el impacto de las modificaciones introducidas durante la ingeniería de características. La comparación con este modelo de referencia permitió tomar decisiones informadas sobre qué transformaciones retener en la búsqueda de una precisión mejorada.
#
# El modelo final que logró la mayor precisión incorporó varias estrategias efectivas. La creación de nuevas imágenes para el conjunto de datos, junto con la normalización por lotes y el uso del dropout, ha demostrado ser crucial. La generación de nuevas instancias de imágenes ayudó al modelo a diversificar su conocimiento, mientras que la normalización por lotes contribuyó a la estabilidad del entrenamiento. La implementación del dropout, una técnica de regularización, resultó fundamental para prevenir el sobreentrenamiento, permitiendo al modelo generalizar de manera más efectiva a datos no vistos.
#
# Experimentar con la arquitectura del modelo, incluyendo el número de capas y neuronas, fue crucial para encontrar la configuración óptima que mejor se adapte a las características específicas del conjunto de datos.
#
# Este proyecto ha proporcionado una base para futuras investigaciones y refinamientos sobre las redes convolucionales.
